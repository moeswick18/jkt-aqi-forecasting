# %%
import matplotlib.pyplot as plt
import pandas as pd
import platform

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Not connected to a GPU

# %%
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# # Monthly

# %%
if platform.system() == 'Windows':
  pm10_monthly = pd.read_csv("..\\Data for model\\so2_meteorolgical_monthly.csv")
elif platform.system() == 'Linux':
  from google.colab import drive
  drive.mount('/content/gdrive')
  pm10_monthly = pd.read_csv("/content/gdrive/Othercomputers/My Laptop (1)/jkt-aqi-forecasting/Model/Data for Model/so2_meteorolgical_monthly.csv")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## SO<sub>2</sub>

# %%
so2_monthly
# Out:
#         tanggal  pm10(ug/m3)  pm10_ispu  so2(ug/m3)  so2_ispu  co(ug/m3)  \
# 0    2010-01-31         41.9         42         4.7         5     2372.3
# 1    2010-02-28         56.2         53         6.0         7     2825.5
# 2    2010-03-31         59.3         55         8.0         9     2897.4
# 3    2010-04-30         59.5         55        12.4        13     2720.0
# 4    2010-05-31         65.2         58        16.3        16     2907.7
# ..          ...          ...        ...         ...       ...        ...
# 115  2019-08-31         68.8         59        19.7        20     1680.0
# 116  2019-09-30         64.3         57        21.6        21     1523.2
# 117  2019-10-31         73.4         62        21.6        21     1540.0
# 118  2019-11-30         65.6         58        23.5        23     1363.2
# 119  2019-12-31         58.3         54        24.3        24     1440.0
#
#      co_ispu  o3(ug/m3)  o3_ispu  no2(ug/m3)  no2_ispu  \
# 0         30       51.0       22        21.8        14
# 1         36       97.1       41        28.7        19
# 2         36      101.1       42        29.2        19
# 3         34      118.3       49        27.1        18
# 4         37      124.3       52        31.1        20
# ..       ...        ...      ...         ...       ...
# 115       22      143.1       60        25.3        16
# 116       20      140.4       59        22.5        15
# 117       20      159.5       67        23.6        15
# 118       18      162.7       69        24.0        16
# 119       19      123.3       51        19.9        13
#
#      temperatur_rata-rata(°C)  kelembapan_rata-rata(%)  curah_hujan(mm)  \
# 0                        27.4                     80.2             14.4
# 1                        28.2                     80.3              9.6
# 2                        28.6                     78.5              9.4
# 3                        29.6                     74.5              2.2
# 4                        29.3                     76.7              2.8
# ..                        ...                      ...              ...
# 115                      28.3                     68.8              0.0
# 116                      28.8                     68.9              0.0
# 117                      29.5                     70.0              0.0
# 118                      29.5                     70.8              2.0
# 119                      28.6                     78.6              8.0
#
#      kecepatan_angin_rata-rata(m/s)
# 0                               2.5
# 1                               2.6
# 2                               2.6
# 3                               2.7
# 4                               2.7
# ..                              ...
# 115                             1.4
# 116                             1.2
# 117                             1.2
# 118                             1.3
# 119                             1.4
#
# [120 rows x 15 columns]

# %%
so2_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   tanggal                         120 non-null    object
#  1   pm10(ug/m3)                     120 non-null    float64
#  2   pm10_ispu                       120 non-null    int64
#  3   so2(ug/m3)                      120 non-null    float64
#  4   so2_ispu                        120 non-null    int64
#  5   co(ug/m3)                       120 non-null    float64
#  6   co_ispu                         120 non-null    int64
#  7   o3(ug/m3)                       120 non-null    float64
#  8   o3_ispu                         120 non-null    int64
#  9   no2(ug/m3)                      120 non-null    float64
#  10  no2_ispu                        120 non-null    int64
#  11  temperatur_rata-rata(°C)        120 non-null    float64
#  12  kelembapan_rata-rata(%)         120 non-null    float64
#  13  curah_hujan(mm)                 120 non-null    float64
#  14  kecepatan_angin_rata-rata(m/s)  120 non-null    float64
# dtypes: float64(9), int64(5), object(1)
# memory usage: 14.2+ KB

# %%
so2_monthly['tanggal'] = pd.to_datetime(so2_monthly['tanggal'], dayfirst=True)
so2_monthly.set_index('tanggal', inplace=True)

# %%
so2_monthly.describe()
# Out:
#        pm10(ug/m3)   pm10_ispu  so2(ug/m3)    so2_ispu    co(ug/m3)  \
# count   120.000000  120.000000  120.000000  120.000000   120.000000
# mean     59.696667   53.766667   17.369167   17.350000  2140.963333
# std      14.937353    9.465313    9.064084    8.516568   458.311636
# min      28.400000   29.000000    1.600000    3.000000  1150.500000
# 25%      50.250000   50.000000    9.000000    9.000000  1772.150000
# 50%      59.450000   55.000000   16.850000   17.000000  2168.800000
# 75%      70.500000   60.250000   23.075000   23.000000  2529.600000
# max     103.200000   77.000000   40.800000   39.000000  3062.400000
#
#           co_ispu   o3(ug/m3)     o3_ispu  no2(ug/m3)    no2_ispu  \
# count  120.000000  120.000000  120.000000  120.000000  120.000000
# mean    27.225000  123.872500   52.133333   20.342500   13.441667
# std      5.590301   40.796987   17.162071   10.281407    6.340209
# min     15.000000   31.100000   14.000000    2.700000    3.000000
# 25%     23.000000   95.125000   40.000000    7.500000    5.750000
# 50%     27.500000  126.200000   52.500000   24.050000   16.000000
# 75%     32.000000  156.550000   66.000000   28.925000   19.000000
# max     39.000000  203.900000   86.000000   37.500000   24.000000
#
#        temperatur_rata-rata(°C)  kelembapan_rata-rata(%)  curah_hujan(mm)  \
# count                120.000000               120.000000       120.000000
# mean                  28.484167                75.831667         5.907500
# std                    0.658365                 4.315148         5.617263
# min                   26.600000                66.300000         0.000000
# 25%                   28.175000                72.750000         1.800000
# 50%                   28.600000                76.300000         5.050000
# 75%                   28.900000                78.600000         8.525000
# max                   29.900000                84.800000        33.000000
#
#        kecepatan_angin_rata-rata(m/s)
# count                      120.000000
# mean                         1.881667
# std                          0.680457
# min                          0.900000
# 25%                          1.300000
# 50%                          1.600000
# 75%                          2.600000
# max                          3.300000

# %%
so2_monthly.corr(method='spearman')
# Out:
#                                 pm10(ug/m3)  pm10_ispu  so2(ug/m3)  so2_ispu  \
# pm10(ug/m3)                        1.000000   0.998846    0.073242  0.066274
# pm10_ispu                          0.998846   1.000000    0.077028  0.070341
# so2(ug/m3)                         0.073242   0.077028    1.000000  0.998928
# so2_ispu                           0.066274   0.070341    0.998928  1.000000
# co(ug/m3)                          0.217009   0.217985   -0.111072 -0.105754
# co_ispu                            0.214419   0.215218   -0.105254 -0.099560
# o3(ug/m3)                          0.320464   0.318720   -0.053265 -0.061366
# o3_ispu                            0.323119   0.321275   -0.049911 -0.058153
# no2(ug/m3)                         0.506270   0.500334   -0.151968 -0.151439
# no2_ispu                           0.496773   0.491054   -0.145419 -0.145055
# temperatur_rata-rata(°C)           0.337487   0.337593    0.141579  0.137976
# kelembapan_rata-rata(%)           -0.365542  -0.359719   -0.234168 -0.227800
# curah_hujan(mm)                   -0.457840  -0.450833   -0.149000 -0.139096
# kecepatan_angin_rata-rata(m/s)    -0.117375  -0.118786   -0.087005 -0.082798
#
#                                 co(ug/m3)   co_ispu  o3(ug/m3)   o3_ispu  \
# pm10(ug/m3)                      0.217009  0.214419   0.320464  0.323119
# pm10_ispu                        0.217985  0.215218   0.318720  0.321275
# so2(ug/m3)                      -0.111072 -0.105254  -0.053265 -0.049911
# so2_ispu                        -0.105754 -0.099560  -0.061366 -0.058153
# co(ug/m3)                        1.000000  0.998476   0.213741  0.212842
# co_ispu                          0.998476  1.000000   0.210402  0.209816
# o3(ug/m3)                        0.213741  0.210402   1.000000  0.999715
# o3_ispu                          0.212842  0.209816   0.999715  1.000000
# no2(ug/m3)                       0.474615  0.473710   0.457211  0.458917
# no2_ispu                         0.480847  0.480386   0.452113  0.454162
# temperatur_rata-rata(°C)        -0.105411 -0.107821   0.314346  0.314866
# kelembapan_rata-rata(%)          0.360797  0.362407  -0.331460 -0.331565
# curah_hujan(mm)                  0.340931  0.341291  -0.274015 -0.275958
# kecepatan_angin_rata-rata(m/s)   0.460545  0.457511   0.319836  0.316290
#
#                                 no2(ug/m3)  no2_ispu  \
# pm10(ug/m3)                       0.506270  0.496773
# pm10_ispu                         0.500334  0.491054
# so2(ug/m3)                       -0.151968 -0.145419
# so2_ispu                         -0.151439 -0.145055
# co(ug/m3)                         0.474615  0.480847
# co_ispu                           0.473710  0.480386
# o3(ug/m3)                         0.457211  0.452113
# o3_ispu                           0.458917  0.454162
# no2(ug/m3)                        1.000000  0.995838
# no2_ispu                          0.995838  1.000000
# temperatur_rata-rata(°C)          0.260025  0.255304
# kelembapan_rata-rata(%)          -0.250964 -0.240835
# curah_hujan(mm)                  -0.261007 -0.250228
# kecepatan_angin_rata-rata(m/s)    0.344120  0.345154
#
#                                 temperatur_rata-rata(°C)  \
# pm10(ug/m3)                                     0.337487
# pm10_ispu                                       0.337593
# so2(ug/m3)                                      0.141579
# so2_ispu                                        0.137976
# co(ug/m3)                                      -0.105411
# co_ispu                                        -0.107821
# o3(ug/m3)                                       0.314346
# o3_ispu                                         0.314866
# no2(ug/m3)                                      0.260025
# no2_ispu                                        0.255304
# temperatur_rata-rata(°C)                        1.000000
# kelembapan_rata-rata(%)                        -0.674751
# curah_hujan(mm)                                -0.598617
# kecepatan_angin_rata-rata(m/s)                 -0.110798
#
#                                 kelembapan_rata-rata(%)  curah_hujan(mm)  \
# pm10(ug/m3)                                   -0.365542        -0.457840
# pm10_ispu                                     -0.359719        -0.450833
# so2(ug/m3)                                    -0.234168        -0.149000
# so2_ispu                                      -0.227800        -0.139096
# co(ug/m3)                                      0.360797         0.340931
# co_ispu                                        0.362407         0.341291
# o3(ug/m3)                                     -0.331460        -0.274015
# o3_ispu                                       -0.331565        -0.275958
# no2(ug/m3)                                    -0.250964        -0.261007
# no2_ispu                                      -0.240835        -0.250228
# temperatur_rata-rata(°C)                      -0.674751        -0.598617
# kelembapan_rata-rata(%)                        1.000000         0.845926
# curah_hujan(mm)                                0.845926         1.000000
# kecepatan_angin_rata-rata(m/s)                 0.006361         0.087252
#
#                                 kecepatan_angin_rata-rata(m/s)
# pm10(ug/m3)                                          -0.117375
# pm10_ispu                                            -0.118786
# so2(ug/m3)                                           -0.087005
# so2_ispu                                             -0.082798
# co(ug/m3)                                             0.460545
# co_ispu                                               0.457511
# o3(ug/m3)                                             0.319836
# o3_ispu                                               0.316290
# no2(ug/m3)                                            0.344120
# no2_ispu                                              0.345154
# temperatur_rata-rata(°C)                             -0.110798
# kelembapan_rata-rata(%)                               0.006361
# curah_hujan(mm)                                       0.087252
# kecepatan_angin_rata-rata(m/s)                        1.000000

# %%
so2_monthly.drop(['pm10(ug/m3)', 'pm10_ispu', 'so2_ispu', 'co_ispu', 'o3(ug/m3)', 'o3_ispu', 'no2_ispu', 'kecepatan_angin_rata-rata(m/s)'], axis=1, inplace=True)

# %% [markdown]
# ### Visualize

# %%
groups = [i for i in range(len(so2_monthly.columns))]
i = 1
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(so2_monthly.values[:, group])
    plt.title(so2_monthly.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %% [markdown]
# ### Sliding Window

# %%
WINDOW_SIZE = 12
FEATURES = so2_monthly.shape[1]

# convert series to supervised learning
def series_to_supervised(index, data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    agg.index = index
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# load dataset
values = so2_monthly.values
# frame as supervised learning
reframed = series_to_supervised(so2_monthly.index, values, WINDOW_SIZE)
# drop columns we don't want to predict
reframed = reframed.iloc[:, :-1*(FEATURES-1)]
'''reframed_x.reset_index(inplace=True)
reframed_y = reframed.iloc[:, 180:-5:6]
reframed_y.reset_index(inplace=True)
reframed = reframed_x.merge(reframed_y)
reframed.set_index('tanggal', inplace=True)'''
reframed
# Out:
#             var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  \
# tanggal
# 2011-01-31         4.7      2372.3        21.8        27.4        80.2
# 2011-02-28         6.0      2825.5        28.7        28.2        80.3
# 2011-03-31         8.0      2897.4        29.2        28.6        78.5
# 2011-04-30        12.4      2720.0        27.1        29.6        74.5
# 2011-05-31        16.3      2907.7        31.1        29.3        76.7
# ...                ...         ...         ...         ...         ...
# 2019-08-31        10.9      1229.3         5.3        28.2        69.9
# 2019-09-30        11.3      1440.0         6.9        28.8        67.5
# 2019-10-31        10.4      1373.3         6.2        29.5        71.3
# 2019-11-30        14.6      1691.4         4.8        28.9        75.2
# 2019-12-31        15.1      1455.2         5.7        28.7        74.8
#
#             var6(t-12)  var1(t-11)  var2(t-11)  var3(t-11)  var4(t-11)  ...  \
# tanggal                                                                 ...
# 2011-01-31        14.4         6.0      2825.5        28.7        28.2  ...
# 2011-02-28         9.6         8.0      2897.4        29.2        28.6  ...
# 2011-03-31         9.4        12.4      2720.0        27.1        29.6  ...
# 2011-04-30         2.2        16.3      2907.7        31.1        29.3  ...
# 2011-05-31         2.8        19.0      2916.0        31.3        28.8  ...
# ...                ...         ...         ...         ...         ...  ...
# 2019-08-31         1.1        11.3      1440.0         6.9        28.8  ...
# 2019-09-30         2.7        10.4      1373.3         6.2        29.5  ...
# 2019-10-31         5.3        14.6      1691.4         4.8        28.9  ...
# 2019-11-30         5.0        15.1      1455.2         5.7        28.7  ...
# 2019-12-31         2.5        16.5      1800.0        15.0        27.5  ...
#
#             var4(t-2)  var5(t-2)  var6(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# tanggal
# 2011-01-31       28.3       77.5        5.9       18.6     2077.2       17.8
# 2011-02-28       27.7       75.8        4.3       17.0     2176.7       20.4
# 2011-03-31       27.2       80.0        5.1       17.8     2256.0       21.1
# 2011-04-30       27.6       79.6        9.1       16.3     1889.7       16.9
# 2011-05-31       27.9       76.0        5.1       18.8     2186.7       22.8
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31       29.2       72.1        0.8       21.8     1741.5       25.3
# 2019-09-30       28.7       67.9        0.0       19.7     1680.0       25.3
# 2019-10-31       28.3       68.8        0.0       21.6     1523.2       22.5
# 2019-11-30       28.8       68.9        0.0       21.6     1540.0       23.6
# 2019-12-31       29.5       70.0        0.0       23.5     1363.2       24.0
#
#             var4(t-1)  var5(t-1)  var6(t-1)  var1(t)
# tanggal
# 2011-01-31       27.7       75.8        4.3     17.0
# 2011-02-28       27.2       80.0        5.1     17.8
# 2011-03-31       27.6       79.6        9.1     16.3
# 2011-04-30       27.9       76.0        5.1     18.8
# 2011-05-31       28.7       74.8        1.8     20.3
# ...               ...        ...        ...      ...
# 2019-08-31       28.7       67.9        0.0     19.7
# 2019-09-30       28.3       68.8        0.0     21.6
# 2019-10-31       28.8       68.9        0.0     21.6
# 2019-11-30       29.5       70.0        0.0     23.5
# 2019-12-31       29.5       70.8        2.0     24.3
#
# [108 rows x 73 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# normalize features
scaler = MinMaxScaler(feature_range=(0,1))
reframed = pd.DataFrame(scaler.fit_transform(reframed), index=reframed.index, columns=reframed.columns)
reframed
# Out:
#             var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  \
# tanggal
# 2011-01-31    0.079082    0.639050    0.548851    0.242424    0.751351
# 2011-02-28    0.112245    0.876092    0.747126    0.484848    0.756757
# 2011-03-31    0.163265    0.913698    0.761494    0.606061    0.659459
# 2011-04-30    0.275510    0.820911    0.701149    0.909091    0.443243
# 2011-05-31    0.375000    0.919086    0.816092    0.818182    0.562162
# ...                ...         ...         ...         ...         ...
# 2019-08-31    0.237245    0.041216    0.074713    0.484848    0.194595
# 2019-09-30    0.247449    0.151420    0.120690    0.666667    0.064865
# 2019-10-31    0.224490    0.116533    0.100575    0.878788    0.270270
# 2019-11-30    0.331633    0.282912    0.060345    0.696970    0.481081
# 2019-12-31    0.344388    0.159370    0.086207    0.636364    0.459459
#
#             var6(t-12)  var1(t-11)  var2(t-11)  var3(t-11)  var4(t-11)  ...  \
# tanggal                                                                 ...
# 2011-01-31    0.436364    0.112245    0.876092    0.747126    0.484848  ...
# 2011-02-28    0.290909    0.163265    0.913698    0.761494    0.606061  ...
# 2011-03-31    0.284848    0.275510    0.820911    0.701149    0.909091  ...
# 2011-04-30    0.066667    0.375000    0.919086    0.816092    0.818182  ...
# 2011-05-31    0.084848    0.443878    0.923427    0.821839    0.666667  ...
# ...                ...         ...         ...         ...         ...  ...
# 2019-08-31    0.033333    0.247449    0.151420    0.120690    0.666667  ...
# 2019-09-30    0.081818    0.224490    0.116533    0.100575    0.878788  ...
# 2019-10-31    0.160606    0.331633    0.282912    0.060345    0.696970  ...
# 2019-11-30    0.151515    0.344388    0.159370    0.086207    0.636364  ...
# 2019-12-31    0.075758    0.380102    0.339714    0.353448    0.272727  ...
#
#             var4(t-2)  var5(t-2)  var6(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  \
# tanggal
# 2011-01-31   0.515152   0.605405   0.178788   0.433673   0.484701   0.433908
# 2011-02-28   0.333333   0.513514   0.130303   0.392857   0.536744   0.508621
# 2011-03-31   0.181818   0.740541   0.154545   0.413265   0.578221   0.528736
# 2011-04-30   0.303030   0.718919   0.275758   0.375000   0.386631   0.408046
# 2011-05-31   0.393939   0.524324   0.154545   0.438776   0.541974   0.577586
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.787879   0.313514   0.024242   0.515306   0.309117   0.649425
# 2019-09-30   0.636364   0.086486   0.000000   0.461735   0.276950   0.649425
# 2019-10-31   0.515152   0.135135   0.000000   0.510204   0.194937   0.568966
# 2019-11-30   0.666667   0.140541   0.000000   0.510204   0.203724   0.600575
# 2019-12-31   0.878788   0.200000   0.000000   0.558673   0.111251   0.612069
#
#             var4(t-1)  var5(t-1)  var6(t-1)   var1(t)
# tanggal
# 2011-01-31   0.333333   0.513514   0.130303  0.392857
# 2011-02-28   0.181818   0.740541   0.154545  0.413265
# 2011-03-31   0.303030   0.718919   0.275758  0.375000
# 2011-04-30   0.393939   0.524324   0.154545  0.438776
# 2011-05-31   0.636364   0.459459   0.054545  0.477041
# ...               ...        ...        ...       ...
# 2019-08-31   0.636364   0.086486   0.000000  0.461735
# 2019-09-30   0.515152   0.135135   0.000000  0.510204
# 2019-10-31   0.666667   0.140541   0.000000  0.510204
# 2019-11-30   0.878788   0.200000   0.000000  0.558673
# 2019-12-31   0.878788   0.243243   0.060606  0.579082
#
# [108 rows x 73 columns]

# %%
from datetime import datetime

train_end = datetime.strptime('2012-12-31', '%Y-%m-%d')
test_start = datetime.strptime('2013-01-01', '%Y-%m-%d')
test_end = datetime.strptime('2019-12-31', '%Y-%m-%d')

train = reframed.loc[:train_end].values
test = reframed.loc[test_start:test_end].values
train_X, train_y = train[:, :-1], train[:, -1:]
test_X, test_y = test[:, :-1], test[:, -1:]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (24, 72) (24, 1) (84, 72) (84, 1)

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], WINDOW_SIZE, FEATURES))
# val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], WINDOW_SIZE, FEATURES))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (24, 12, 6) (24, 1) (84, 12, 6) (84, 1)

# %%
# !pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.8/dist-packages (1.1.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (7.9.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.0.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.18.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->keras_tuner) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2022.12.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (2.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.51.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.4.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.19.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras_tuner) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (6.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.2)

# %%
from tensorflow.keras.layers import Dense, Dropout, InputLayer
from tensorflow.keras.layers import LSTM
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
import keras_tuner as kt

'''# design network
model = Sequential()
model.add(InputLayer((train_X.shape[1], train_X.shape[2])))
model.add(LSTM(6))
model.add(Dense(1))
model.compile(loss=Huber(), optimizer=Adam(learning_rate=0.001), metrics=RootMeanSquaredError())
# fit network
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_root_mean_squared_error', patience=24)
history = model.fit(train_X, train_y, epochs=175, batch_size=24, validation_data=(val_X, val_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()'''
def call_existing_code(num_layers, units, activation, dropout, dropout_rate, lr):
    model = Sequential()
    model.add(InputLayer((train_X.shape[1], train_X.shape[2])))
    for i in range(num_layers):
      model.add(LSTM(units=units[i], return_sequences=True))
    model.add(LSTM(units=units[-1]))
    if dropout:
        model.add(Dropout(rate=dropout_rate))
    model.add(Dense(1, activation=activation))
    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss=Huber(),
        metrics=RootMeanSquaredError(),
    )
    return model


def build_model(hp):
    num_layers = hp.Int("num_layers", min_value=1, max_value=3)
    units_i = []
    for i in range(num_layers):
      units_i.append(hp.Int(f"units_{i}", min_value=10, max_value=100, step=10))
    units_i.append(hp.Int("units", min_value=10, max_value=100, step=10))
    activation = hp.Choice("activation", ["relu", "tanh", "linear"])
    dropout = hp.Boolean("dropout")
    dropout_rate = hp.Float("dropout_1", min_value=0.1, max_value=0.2, step=0.1)
    lr = hp.Float("lr", min_value=1e-3, max_value=1e-2, default=1e-2)
    # call existing model-building code with the hyperparameter values.
    model = call_existing_code(
        num_layers=num_layers, units=units_i, activation=activation, dropout=dropout, dropout_rate=dropout_rate, lr=lr
    )
    return model


build_model(kt.HyperParameters())

# %%
class MyTuner(kt.tuners.BayesianOptimization):
    def run_trial(self, trial, *args, **kwargs):
        # You can add additional HyperParameters for preprocessing and custom training loops
        # via overriding `run_trial`
        kwargs['batch_size'] = trial.hyperparameters.Int('batch_size', min_value=1, max_value=60, step=1)
        kwargs['epochs'] = trial.hyperparameters.Int('epochs', min_value=1, max_value=500, step=1)
        return super(MyTuner, self).run_trial(trial, *args, **kwargs)

if platform.system() == 'Windows':
  tuner = MyTuner(
    hypermodel=build_model,
    objective=kt.Objective("val_root_mean_squared_error", direction="min"),
    max_trials=100,
    executions_per_trial=1,
    overwrite=False,
    directory="D:\\From External Drive\\Kuliah\\Tugas Akhir\\undergraduate-thesis_2.0\\data-and-model\\Model",
    project_name="lstm_so2_monthly_80-20_result"
  )
elif platform.system() == 'Linux':
  tuner = MyTuner(
    hypermodel=build_model,
    objective=kt.Objective("val_root_mean_squared_error", direction="min"),
    max_trials=100,
    executions_per_trial=1,
    overwrite=False,
    directory="/content/gdrive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model",
    project_name="lstm_so2_monthly_80-20_result"
  )

if platform.system() == 'Windows':
  tuner.search(x=train_X, y=train_y, validation_data=(test_X, test_y), shuffle=False, callbacks=[TensorBoard("D:\\From External Drive\\Kuliah\\Tugas Akhir\\undergraduate-thesis_2.0\\data-and-model\\Model\\lstm_so2_monthly_80-20_log")])
elif platform.system() == 'Linux':
  tuner.search(x=train_X, y=train_y, validation_data=(test_X, test_y), shuffle=False, callbacks=[TensorBoard("/content/gdrive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model/lstm_so2_monthly_80-20_log")])

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in /content/gdrive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model/lstm_so2_monthly_80-20_result
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f3613467580>
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: False
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 6
# epochs: 500
# units_1: 100
# units_2: 30
# Score: 0.09540475159883499
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 6
# epochs: 500
# units_1: 100
# units_2: 70
# Score: 0.10334969311952591
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 10
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 1
# epochs: 500
# units_1: 100
# units_2: 100
# Score: 0.10565581917762756
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: False
# dropout_1: 0.1
# lr: 0.010000000000000002
# batch_size: 1
# epochs: 500
# units_1: 100
# units_2: 10
# Score: 0.10629087686538696
# Trial summary
# Hyperparameters:
# num_layers: 3
# units_0: 10
# units: 100
# activation: linear
# dropout: False
# dropout_1: 0.1
# lr: 0.010000000000000002
# batch_size: 12
# epochs: 500
# units_1: 100
# units_2: 10
# Score: 0.10745915025472641
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 20
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 1
# epochs: 500
# units_1: 10
# units_2: 100
# Score: 0.10954181104898453
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 50
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 9
# epochs: 500
# units_1: 100
# units_2: 100
# Score: 0.11132685095071793
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 1
# epochs: 500
# units_1: 100
# units_2: 10
# Score: 0.112217478454113
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: False
# dropout_1: 0.2
# lr: 0.0066546895193502435
# batch_size: 1
# epochs: 500
# units_1: 100
# units_2: 20
# Score: 0.11242160201072693
# Trial summary
# Hyperparameters:
# num_layers: 1
# units_0: 10
# units: 100
# activation: linear
# dropout: True
# dropout_1: 0.2
# lr: 0.010000000000000002
# batch_size: 1
# epochs: 500
# units_1: 100
# units_2: 70
# Score: 0.11350024491548538

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model.build(input_shape=((train_X.shape[1], train_X.shape[2])))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 10)            680
#
#  lstm_1 (LSTM)               (None, 100)               44400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 45,181
# Trainable params: 45,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.evaluate(test_X, test_y)
# Out:
# 3/3 [==============================] - 2s 13ms/step - loss: 0.0053 - root_mean_squared_error: 0.1025
# [0.005252317991107702, 0.10249212384223938]

# %%
best_hp = tuner.get_best_hyperparameters(10)[0]
best_model = build_model(best_hp)
best_model.fit(x=train_X, y=train_y, validation_data=(test_X, test_y), epochs=500, batch_size=6, shuffle=False)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 10s 879ms/step - loss: 0.0797 - root_mean_squared_error: 0.3993 - val_loss: 0.0512 - val_root_mean_squared_error: 0.3199
# Epoch 2/500
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0168 - root_mean_squared_error: 0.1834 - val_loss: 0.0811 - val_root_mean_squared_error: 0.4026
# Epoch 3/500
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0355 - root_mean_squared_error: 0.2663 - val_loss: 0.0360 - val_root_mean_squared_error: 0.2683
# Epoch 4/500
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0195 - root_mean_squared_error: 0.1975 - val_loss: 0.0340 - val_root_mean_squared_error: 0.2606
# Epoch 5/500
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0077 - root_mean_squared_error: 0.1243 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2927
# Epoch 6/500
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0111 - root_mean_squared_error: 0.1493 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2971
# Epoch 7/500
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0119 - root_mean_squared_error: 0.1545 - val_loss: 0.0350 - val_root_mean_squared_error: 0.2644
# Epoch 8/500
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0104 - root_mean_squared_error: 0.1439 - val_loss: 0.0332 - val_root_mean_squared_error: 0.2578
# Epoch 9/500
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0089 - root_mean_squared_error: 0.1331 - val_loss: 0.0347 - val_root_mean_squared_error: 0.2635
# Epoch 10/500
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0077 - root_mean_squared_error: 0.1244 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2749
# Epoch 11/500
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0088 - root_mean_squared_error: 0.1330 - val_loss: 0.0368 - val_root_mean_squared_error: 0.2714
# Epoch 12/500
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0090 - root_mean_squared_error: 0.1343 - val_loss: 0.0339 - val_root_mean_squared_error: 0.2605
# Epoch 13/500
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0085 - root_mean_squared_error: 0.1300 - val_loss: 0.0331 - val_root_mean_squared_error: 0.2574
# Epoch 14/500
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0076 - root_mean_squared_error: 0.1235 - val_loss: 0.0340 - val_root_mean_squared_error: 0.2607
# Epoch 15/500
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0075 - root_mean_squared_error: 0.1228 - val_loss: 0.0339 - val_root_mean_squared_error: 0.2605
# Epoch 16/500
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0077 - root_mean_squared_error: 0.1244 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2528
# Epoch 17/500
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0071 - root_mean_squared_error: 0.1194 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2494
# Epoch 18/500
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0063 - root_mean_squared_error: 0.1125 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2480
# Epoch 19/500
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0060 - root_mean_squared_error: 0.1095 - val_loss: 0.0291 - val_root_mean_squared_error: 0.2412
# Epoch 20/500
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0054 - root_mean_squared_error: 0.1040 - val_loss: 0.0289 - val_root_mean_squared_error: 0.2405
# Epoch 21/500
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0062 - root_mean_squared_error: 0.1117 - val_loss: 0.0297 - val_root_mean_squared_error: 0.2438
# Epoch 22/500
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0053 - root_mean_squared_error: 0.1030 - val_loss: 0.0294 - val_root_mean_squared_error: 0.2423
# Epoch 23/500
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0049 - root_mean_squared_error: 0.0989 - val_loss: 0.0299 - val_root_mean_squared_error: 0.2447
# Epoch 24/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0050 - root_mean_squared_error: 0.0995 - val_loss: 0.0291 - val_root_mean_squared_error: 0.2413
# Epoch 25/500
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0044 - root_mean_squared_error: 0.0940 - val_loss: 0.0288 - val_root_mean_squared_error: 0.2401
# Epoch 26/500
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0044 - root_mean_squared_error: 0.0943 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2454
# Epoch 27/500
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0040 - root_mean_squared_error: 0.0893 - val_loss: 0.0286 - val_root_mean_squared_error: 0.2393
# Epoch 28/500
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0042 - root_mean_squared_error: 0.0914 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2500
# Epoch 29/500
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0040 - root_mean_squared_error: 0.0897 - val_loss: 0.0287 - val_root_mean_squared_error: 0.2397
# Epoch 30/500
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0040 - root_mean_squared_error: 0.0891 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2505
# Epoch 31/500
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0039 - root_mean_squared_error: 0.0887 - val_loss: 0.0288 - val_root_mean_squared_error: 0.2398
# Epoch 32/500
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0040 - root_mean_squared_error: 0.0900 - val_loss: 0.0316 - val_root_mean_squared_error: 0.2515
# Epoch 33/500
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0039 - root_mean_squared_error: 0.0879 - val_loss: 0.0300 - val_root_mean_squared_error: 0.2449
# Epoch 34/500
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0041 - root_mean_squared_error: 0.0901 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2493
# Epoch 35/500
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0042 - root_mean_squared_error: 0.0914 - val_loss: 0.0317 - val_root_mean_squared_error: 0.2520
# Epoch 36/500
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0049 - root_mean_squared_error: 0.0988 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2456
# Epoch 37/500
# 4/4 [==============================] - 0s 101ms/step - loss: 0.0034 - root_mean_squared_error: 0.0827 - val_loss: 0.0354 - val_root_mean_squared_error: 0.2661
# Epoch 38/500
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0040 - root_mean_squared_error: 0.0892 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2487
# Epoch 39/500
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0039 - root_mean_squared_error: 0.0884 - val_loss: 0.0336 - val_root_mean_squared_error: 0.2594
# Epoch 40/500
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0043 - root_mean_squared_error: 0.0922 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2457
# Epoch 41/500
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0043 - root_mean_squared_error: 0.0929 - val_loss: 0.0335 - val_root_mean_squared_error: 0.2588
# Epoch 42/500
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0038 - root_mean_squared_error: 0.0876 - val_loss: 0.0325 - val_root_mean_squared_error: 0.2548
# Epoch 43/500
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0033 - root_mean_squared_error: 0.0816 - val_loss: 0.0348 - val_root_mean_squared_error: 0.2637
# Epoch 44/500
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0047 - root_mean_squared_error: 0.0967 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2456
# Epoch 45/500
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0037 - root_mean_squared_error: 0.0866 - val_loss: 0.0340 - val_root_mean_squared_error: 0.2607
# Epoch 46/500
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0042 - root_mean_squared_error: 0.0916 - val_loss: 0.0305 - val_root_mean_squared_error: 0.2471
# Epoch 47/500
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0033 - root_mean_squared_error: 0.0808 - val_loss: 0.0371 - val_root_mean_squared_error: 0.2723
# Epoch 48/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0041 - root_mean_squared_error: 0.0903 - val_loss: 0.0325 - val_root_mean_squared_error: 0.2548
# Epoch 49/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0036 - root_mean_squared_error: 0.0844 - val_loss: 0.0367 - val_root_mean_squared_error: 0.2708
# Epoch 50/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0033 - root_mean_squared_error: 0.0808 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2488
# Epoch 51/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0031 - root_mean_squared_error: 0.0789 - val_loss: 0.0326 - val_root_mean_squared_error: 0.2555
# Epoch 52/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0032 - root_mean_squared_error: 0.0798 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2504
# Epoch 53/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0028 - root_mean_squared_error: 0.0742 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2534
# Epoch 54/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0025 - root_mean_squared_error: 0.0711 - val_loss: 0.0340 - val_root_mean_squared_error: 0.2609
# Epoch 55/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0022 - root_mean_squared_error: 0.0658 - val_loss: 0.0337 - val_root_mean_squared_error: 0.2597
# Epoch 56/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0025 - root_mean_squared_error: 0.0714 - val_loss: 0.0345 - val_root_mean_squared_error: 0.2627
# Epoch 57/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0022 - root_mean_squared_error: 0.0668 - val_loss: 0.0342 - val_root_mean_squared_error: 0.2616
# Epoch 58/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0020 - root_mean_squared_error: 0.0636 - val_loss: 0.0344 - val_root_mean_squared_error: 0.2622
# Epoch 59/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0018 - root_mean_squared_error: 0.0598 - val_loss: 0.0342 - val_root_mean_squared_error: 0.2616
# Epoch 60/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0019 - root_mean_squared_error: 0.0616 - val_loss: 0.0343 - val_root_mean_squared_error: 0.2621
# Epoch 61/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0017 - root_mean_squared_error: 0.0589 - val_loss: 0.0346 - val_root_mean_squared_error: 0.2632
# Epoch 62/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0016 - root_mean_squared_error: 0.0562 - val_loss: 0.0344 - val_root_mean_squared_error: 0.2624
# Epoch 63/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0016 - root_mean_squared_error: 0.0560 - val_loss: 0.0355 - val_root_mean_squared_error: 0.2665
# Epoch 64/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0012 - root_mean_squared_error: 0.0489 - val_loss: 0.0360 - val_root_mean_squared_error: 0.2684
# Epoch 65/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0013 - root_mean_squared_error: 0.0507 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2729
# Epoch 66/500
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0051 - root_mean_squared_error: 0.1006 - val_loss: 0.0387 - val_root_mean_squared_error: 0.2782
# Epoch 67/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0076 - root_mean_squared_error: 0.1236 - val_loss: 0.0356 - val_root_mean_squared_error: 0.2668
# Epoch 68/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0102 - root_mean_squared_error: 0.1425 - val_loss: 0.0333 - val_root_mean_squared_error: 0.2581
# Epoch 69/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0069 - root_mean_squared_error: 0.1172 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2747
# Epoch 70/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0097 - root_mean_squared_error: 0.1392 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2506
# Epoch 71/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0065 - root_mean_squared_error: 0.1139 - val_loss: 0.0337 - val_root_mean_squared_error: 0.2598
# Epoch 72/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0065 - root_mean_squared_error: 0.1140 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537
# Epoch 73/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0058 - root_mean_squared_error: 0.1076 - val_loss: 0.0294 - val_root_mean_squared_error: 0.2423
# Epoch 74/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0036 - root_mean_squared_error: 0.0843 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2506
# Epoch 75/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0031 - root_mean_squared_error: 0.0783 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2493
# Epoch 76/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0036 - root_mean_squared_error: 0.0845 - val_loss: 0.0332 - val_root_mean_squared_error: 0.2578
# Epoch 77/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0024 - root_mean_squared_error: 0.0696 - val_loss: 0.0345 - val_root_mean_squared_error: 0.2625
# Epoch 78/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0020 - root_mean_squared_error: 0.0633 - val_loss: 0.0339 - val_root_mean_squared_error: 0.2603
# Epoch 79/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018 - root_mean_squared_error: 0.0603 - val_loss: 0.0345 - val_root_mean_squared_error: 0.2626
# Epoch 80/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0017 - root_mean_squared_error: 0.0583 - val_loss: 0.0332 - val_root_mean_squared_error: 0.2576
# Epoch 81/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0016 - root_mean_squared_error: 0.0566 - val_loss: 0.0334 - val_root_mean_squared_error: 0.2584
# Epoch 82/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0014 - root_mean_squared_error: 0.0532 - val_loss: 0.0335 - val_root_mean_squared_error: 0.2587
# Epoch 83/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - root_mean_squared_error: 0.0513 - val_loss: 0.0350 - val_root_mean_squared_error: 0.2645
# Epoch 84/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0011 - root_mean_squared_error: 0.0465 - val_loss: 0.0365 - val_root_mean_squared_error: 0.2700
# Epoch 85/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0010 - root_mean_squared_error: 0.0457 - val_loss: 0.0381 - val_root_mean_squared_error: 0.2761
# Epoch 86/500
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0013 - root_mean_squared_error: 0.0502 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2837
# Epoch 87/500
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0016 - root_mean_squared_error: 0.0557 - val_loss: 0.0464 - val_root_mean_squared_error: 0.3045
# Epoch 88/500
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0046 - root_mean_squared_error: 0.0956 - val_loss: 0.0358 - val_root_mean_squared_error: 0.2675
# Epoch 89/500
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0044 - root_mean_squared_error: 0.0938 - val_loss: 0.0368 - val_root_mean_squared_error: 0.2713
# Epoch 90/500
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0038 - root_mean_squared_error: 0.0876 - val_loss: 0.0363 - val_root_mean_squared_error: 0.2693
# Epoch 91/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0031 - root_mean_squared_error: 0.0790 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2452
# Epoch 92/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0025 - root_mean_squared_error: 0.0711 - val_loss: 0.0295 - val_root_mean_squared_error: 0.2428
# Epoch 93/500
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0021 - root_mean_squared_error: 0.0641 - val_loss: 0.0294 - val_root_mean_squared_error: 0.2426
# Epoch 94/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0018 - root_mean_squared_error: 0.0594 - val_loss: 0.0285 - val_root_mean_squared_error: 0.2389
# Epoch 95/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0017 - root_mean_squared_error: 0.0583 - val_loss: 0.0299 - val_root_mean_squared_error: 0.2444
# Epoch 96/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0549 - val_loss: 0.0293 - val_root_mean_squared_error: 0.2420
# Epoch 97/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0014 - root_mean_squared_error: 0.0524 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2486
# Epoch 98/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0012 - root_mean_squared_error: 0.0480 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2536
# Epoch 99/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0010 - root_mean_squared_error: 0.0447 - val_loss: 0.0334 - val_root_mean_squared_error: 0.2584
# Epoch 100/500
# 4/4 [==============================] - 0s 32ms/step - loss: 8.3324e-04 - root_mean_squared_error: 0.0408 - val_loss: 0.0346 - val_root_mean_squared_error: 0.2630
# Epoch 101/500
# 4/4 [==============================] - 0s 36ms/step - loss: 7.5103e-04 - root_mean_squared_error: 0.0388 - val_loss: 0.0357 - val_root_mean_squared_error: 0.2674
# Epoch 102/500
# 4/4 [==============================] - 0s 36ms/step - loss: 7.0546e-04 - root_mean_squared_error: 0.0376 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2727
# Epoch 103/500
# 4/4 [==============================] - 0s 31ms/step - loss: 6.5140e-04 - root_mean_squared_error: 0.0361 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2770
# Epoch 104/500
# 4/4 [==============================] - 0s 37ms/step - loss: 6.2870e-04 - root_mean_squared_error: 0.0355 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2815
# Epoch 105/500
# 4/4 [==============================] - 0s 32ms/step - loss: 6.3879e-04 - root_mean_squared_error: 0.0357 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2849
# Epoch 106/500
# 4/4 [==============================] - 0s 32ms/step - loss: 6.1547e-04 - root_mean_squared_error: 0.0351 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2862
# Epoch 107/500
# 4/4 [==============================] - 0s 31ms/step - loss: 6.1309e-04 - root_mean_squared_error: 0.0350 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2867
# Epoch 108/500
# 4/4 [==============================] - 0s 38ms/step - loss: 6.0871e-04 - root_mean_squared_error: 0.0349 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2882
# Epoch 109/500
# 4/4 [==============================] - 0s 39ms/step - loss: 6.1975e-04 - root_mean_squared_error: 0.0352 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2889
# Epoch 110/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.7348e-04 - root_mean_squared_error: 0.0339 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2876
# Epoch 111/500
# 4/4 [==============================] - 0s 37ms/step - loss: 6.2357e-04 - root_mean_squared_error: 0.0353 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2869
# Epoch 112/500
# 4/4 [==============================] - 0s 36ms/step - loss: 6.2277e-04 - root_mean_squared_error: 0.0353 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2888
# Epoch 113/500
# 4/4 [==============================] - 0s 35ms/step - loss: 6.9161e-04 - root_mean_squared_error: 0.0372 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2881
# Epoch 114/500
# 4/4 [==============================] - 0s 32ms/step - loss: 6.2785e-04 - root_mean_squared_error: 0.0354 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2836
# Epoch 115/500
# 4/4 [==============================] - 0s 42ms/step - loss: 7.3750e-04 - root_mean_squared_error: 0.0384 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2834
# Epoch 116/500
# 4/4 [==============================] - 0s 31ms/step - loss: 8.8348e-04 - root_mean_squared_error: 0.0420 - val_loss: 0.0398 - val_root_mean_squared_error: 0.2820
# Epoch 117/500
# 4/4 [==============================] - 0s 36ms/step - loss: 5.6865e-04 - root_mean_squared_error: 0.0337 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2816
# Epoch 118/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.3610e-04 - root_mean_squared_error: 0.0327 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2813
# Epoch 119/500
# 4/4 [==============================] - 0s 37ms/step - loss: 5.1503e-04 - root_mean_squared_error: 0.0321 - val_loss: 0.0393 - val_root_mean_squared_error: 0.2804
# Epoch 120/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.4698e-04 - root_mean_squared_error: 0.0331 - val_loss: 0.0397 - val_root_mean_squared_error: 0.2818
# Epoch 121/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.1861e-04 - root_mean_squared_error: 0.0322 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2845
# Epoch 122/500
# 4/4 [==============================] - 0s 33ms/step - loss: 6.6029e-04 - root_mean_squared_error: 0.0363 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2827
# Epoch 123/500
# 4/4 [==============================] - 0s 32ms/step - loss: 5.5703e-04 - root_mean_squared_error: 0.0334 - val_loss: 0.0393 - val_root_mean_squared_error: 0.2804
# Epoch 124/500
# 4/4 [==============================] - 0s 32ms/step - loss: 5.7756e-04 - root_mean_squared_error: 0.0340 - val_loss: 0.0395 - val_root_mean_squared_error: 0.2809
# Epoch 125/500
# 4/4 [==============================] - 0s 38ms/step - loss: 5.7083e-04 - root_mean_squared_error: 0.0338 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2832
# Epoch 126/500
# 4/4 [==============================] - 0s 33ms/step - loss: 6.1184e-04 - root_mean_squared_error: 0.0350 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2816
# Epoch 127/500
# 4/4 [==============================] - 0s 38ms/step - loss: 6.4839e-04 - root_mean_squared_error: 0.0360 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2788
# Epoch 128/500
# 4/4 [==============================] - 0s 39ms/step - loss: 6.0955e-04 - root_mean_squared_error: 0.0349 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2790
# Epoch 129/500
# 4/4 [==============================] - 0s 77ms/step - loss: 8.3897e-04 - root_mean_squared_error: 0.0410 - val_loss: 0.0383 - val_root_mean_squared_error: 0.2768
# Epoch 130/500
# 4/4 [==============================] - 0s 37ms/step - loss: 6.4925e-04 - root_mean_squared_error: 0.0360 - val_loss: 0.0386 - val_root_mean_squared_error: 0.2780
# Epoch 131/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.8068e-04 - root_mean_squared_error: 0.0341 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2774
# Epoch 132/500
# 4/4 [==============================] - 0s 41ms/step - loss: 5.4298e-04 - root_mean_squared_error: 0.0330 - val_loss: 0.0371 - val_root_mean_squared_error: 0.2725
# Epoch 133/500
# 4/4 [==============================] - 0s 33ms/step - loss: 6.9579e-04 - root_mean_squared_error: 0.0373 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2729
# Epoch 134/500
# 4/4 [==============================] - 0s 32ms/step - loss: 6.5208e-04 - root_mean_squared_error: 0.0361 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2737
# Epoch 135/500
# 4/4 [==============================] - 0s 32ms/step - loss: 5.2267e-04 - root_mean_squared_error: 0.0323 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2737
# Epoch 136/500
# 4/4 [==============================] - 0s 38ms/step - loss: 4.5873e-04 - root_mean_squared_error: 0.0303 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2754
# Epoch 137/500
# 4/4 [==============================] - 0s 32ms/step - loss: 4.6057e-04 - root_mean_squared_error: 0.0304 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2746
# Epoch 138/500
# 4/4 [==============================] - 0s 32ms/step - loss: 4.6662e-04 - root_mean_squared_error: 0.0305 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2738
# Epoch 139/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.2850e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2758
# Epoch 140/500
# 4/4 [==============================] - 0s 37ms/step - loss: 4.3768e-04 - root_mean_squared_error: 0.0296 - val_loss: 0.0383 - val_root_mean_squared_error: 0.2767
# Epoch 141/500
# 4/4 [==============================] - 0s 38ms/step - loss: 4.2411e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.0383 - val_root_mean_squared_error: 0.2767
# Epoch 142/500
# 4/4 [==============================] - 0s 34ms/step - loss: 3.9424e-04 - root_mean_squared_error: 0.0281 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2775
# Epoch 143/500
# 4/4 [==============================] - 0s 33ms/step - loss: 3.8718e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2776
# Epoch 144/500
# 4/4 [==============================] - 0s 31ms/step - loss: 3.8877e-04 - root_mean_squared_error: 0.0279 - val_loss: 0.0386 - val_root_mean_squared_error: 0.2779
# Epoch 145/500
# 4/4 [==============================] - 0s 32ms/step - loss: 3.7797e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2791
# Epoch 146/500
# 4/4 [==============================] - 0s 36ms/step - loss: 3.7865e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2793
# Epoch 147/500
# 4/4 [==============================] - 0s 33ms/step - loss: 3.7995e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0388 - val_root_mean_squared_error: 0.2786
# Epoch 148/500
# 4/4 [==============================] - 0s 34ms/step - loss: 3.8097e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2790
# Epoch 149/500
# 4/4 [==============================] - 0s 32ms/step - loss: 3.7063e-04 - root_mean_squared_error: 0.0272 - val_loss: 0.0394 - val_root_mean_squared_error: 0.2808
# Epoch 150/500
# 4/4 [==============================] - 0s 32ms/step - loss: 4.1010e-04 - root_mean_squared_error: 0.0286 - val_loss: 0.0392 - val_root_mean_squared_error: 0.2800
# Epoch 151/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.5358e-04 - root_mean_squared_error: 0.0301 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2776
# Epoch 152/500
# 4/4 [==============================] - 0s 37ms/step - loss: 4.4038e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2792
# Epoch 153/500
# 4/4 [==============================] - 0s 41ms/step - loss: 5.8616e-04 - root_mean_squared_error: 0.0342 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2814
# Epoch 154/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.1707e-04 - root_mean_squared_error: 0.0322 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2773
# Epoch 155/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.2445e-04 - root_mean_squared_error: 0.0324 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2737
# Epoch 156/500
# 4/4 [==============================] - 0s 37ms/step - loss: 5.4124e-04 - root_mean_squared_error: 0.0329 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2754
# Epoch 157/500
# 4/4 [==============================] - 0s 35ms/step - loss: 5.5176e-04 - root_mean_squared_error: 0.0332 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2771
# Epoch 158/500
# 4/4 [==============================] - 0s 34ms/step - loss: 6.1072e-04 - root_mean_squared_error: 0.0349 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2757
# Epoch 159/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.8326e-04 - root_mean_squared_error: 0.0311 - val_loss: 0.0373 - val_root_mean_squared_error: 0.2731
# Epoch 160/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.4813e-04 - root_mean_squared_error: 0.0299 - val_loss: 0.0368 - val_root_mean_squared_error: 0.2713
# Epoch 161/500
# 4/4 [==============================] - 0s 38ms/step - loss: 4.3398e-04 - root_mean_squared_error: 0.0295 - val_loss: 0.0373 - val_root_mean_squared_error: 0.2731
# Epoch 162/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.6585e-04 - root_mean_squared_error: 0.0305 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2738
# Epoch 163/500
# 4/4 [==============================] - 0s 39ms/step - loss: 5.0320e-04 - root_mean_squared_error: 0.0317 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2744
# Epoch 164/500
# 4/4 [==============================] - 0s 35ms/step - loss: 3.8121e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2750
# Epoch 165/500
# 4/4 [==============================] - 0s 40ms/step - loss: 3.5385e-04 - root_mean_squared_error: 0.0266 - val_loss: 0.0371 - val_root_mean_squared_error: 0.2724
# Epoch 166/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.3225e-04 - root_mean_squared_error: 0.0294 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2743
# Epoch 167/500
# 4/4 [==============================] - 0s 39ms/step - loss: 4.3066e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2770
# Epoch 168/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.1715e-04 - root_mean_squared_error: 0.0289 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2746
# Epoch 169/500
# 4/4 [==============================] - 0s 64ms/step - loss: 4.2921e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2744
# Epoch 170/500
# 4/4 [==============================] - 0s 84ms/step - loss: 4.4599e-04 - root_mean_squared_error: 0.0299 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2749
# Epoch 171/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.0593e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2751
# Epoch 172/500
# 4/4 [==============================] - 0s 39ms/step - loss: 3.4856e-04 - root_mean_squared_error: 0.0264 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2757
# Epoch 173/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.2254e-04 - root_mean_squared_error: 0.0254 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2742
# Epoch 174/500
# 4/4 [==============================] - 0s 35ms/step - loss: 3.8681e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2752
# Epoch 175/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.5604e-04 - root_mean_squared_error: 0.0267 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2771
# Epoch 176/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.7342e-04 - root_mean_squared_error: 0.0273 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2749
# Epoch 177/500
# 4/4 [==============================] - 0s 35ms/step - loss: 4.3516e-04 - root_mean_squared_error: 0.0295 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2745
# Epoch 178/500
# 4/4 [==============================] - 0s 41ms/step - loss: 4.6055e-04 - root_mean_squared_error: 0.0303 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2755
# Epoch 179/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.9757e-04 - root_mean_squared_error: 0.0282 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2752
# Epoch 180/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.5790e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2746
# Epoch 181/500
# 4/4 [==============================] - 0s 33ms/step - loss: 3.5009e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2739
# Epoch 182/500
# 4/4 [==============================] - 0s 41ms/step - loss: 3.7994e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2755
# Epoch 183/500
# 4/4 [==============================] - 0s 34ms/step - loss: 3.4765e-04 - root_mean_squared_error: 0.0264 - val_loss: 0.0382 - val_root_mean_squared_error: 0.2766
# Epoch 184/500
# 4/4 [==============================] - 0s 37ms/step - loss: 3.9256e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2742
# Epoch 185/500
# 4/4 [==============================] - 0s 36ms/step - loss: 4.1213e-04 - root_mean_squared_error: 0.0287 - val_loss: 0.0375 - val_root_mean_squared_error: 0.2739
# Epoch 186/500
# 4/4 [==============================] - 0s 40ms/step - loss: 4.9267e-04 - root_mean_squared_error: 0.0314 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2746
# Epoch 187/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.2315e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.0381 - val_root_mean_squared_error: 0.2760
# Epoch 188/500
# 4/4 [==============================] - 0s 37ms/step - loss: 3.5459e-04 - root_mean_squared_error: 0.0266 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2750
# Epoch 189/500
# 4/4 [==============================] - 0s 32ms/step - loss: 3.9743e-04 - root_mean_squared_error: 0.0282 - val_loss: 0.0369 - val_root_mean_squared_error: 0.2717
# Epoch 190/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.0561e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.0374 - val_root_mean_squared_error: 0.2735
# Epoch 191/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.7957e-04 - root_mean_squared_error: 0.0310 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2745
# Epoch 192/500
# 4/4 [==============================] - 0s 32ms/step - loss: 5.1475e-04 - root_mean_squared_error: 0.0321 - val_loss: 0.0382 - val_root_mean_squared_error: 0.2763
# Epoch 193/500
# 4/4 [==============================] - 0s 35ms/step - loss: 4.6174e-04 - root_mean_squared_error: 0.0304 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2744
# Epoch 194/500
# 4/4 [==============================] - 0s 37ms/step - loss: 5.2611e-04 - root_mean_squared_error: 0.0324 - val_loss: 0.0364 - val_root_mean_squared_error: 0.2698
# Epoch 195/500
# 4/4 [==============================] - 0s 32ms/step - loss: 3.6922e-04 - root_mean_squared_error: 0.0272 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2728
# Epoch 196/500
# 4/4 [==============================] - 0s 33ms/step - loss: 2.7962e-04 - root_mean_squared_error: 0.0236 - val_loss: 0.0373 - val_root_mean_squared_error: 0.2733
# Epoch 197/500
# 4/4 [==============================] - 0s 40ms/step - loss: 3.7851e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2756
# Epoch 198/500
# 4/4 [==============================] - 0s 31ms/step - loss: 3.5833e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2757
# Epoch 199/500
# 4/4 [==============================] - 0s 31ms/step - loss: 3.9958e-04 - root_mean_squared_error: 0.0283 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2727
# Epoch 200/500
# 4/4 [==============================] - 0s 32ms/step - loss: 3.0660e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2744
# Epoch 201/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.5343e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0374 - val_root_mean_squared_error: 0.2736
# Epoch 202/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.4181e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0379 - val_root_mean_squared_error: 0.2753
# Epoch 203/500
# 4/4 [==============================] - 0s 32ms/step - loss: 2.2887e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.0382 - val_root_mean_squared_error: 0.2763
# Epoch 204/500
# 4/4 [==============================] - 0s 33ms/step - loss: 2.4609e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2757
# Epoch 205/500
# 4/4 [==============================] - 0s 36ms/step - loss: 2.2171e-04 - root_mean_squared_error: 0.0211 - val_loss: 0.0383 - val_root_mean_squared_error: 0.2766
# Epoch 206/500
# 4/4 [==============================] - 0s 33ms/step - loss: 2.1729e-04 - root_mean_squared_error: 0.0208 - val_loss: 0.0383 - val_root_mean_squared_error: 0.2767
# Epoch 207/500
# 4/4 [==============================] - 0s 32ms/step - loss: 2.1972e-04 - root_mean_squared_error: 0.0210 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2770
# Epoch 208/500
# 4/4 [==============================] - 0s 31ms/step - loss: 2.0524e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.0386 - val_root_mean_squared_error: 0.2780
# Epoch 209/500
# 4/4 [==============================] - 0s 67ms/step - loss: 2.0634e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.0387 - val_root_mean_squared_error: 0.2781
# Epoch 210/500
# 4/4 [==============================] - 0s 56ms/step - loss: 1.9938e-04 - root_mean_squared_error: 0.0200 - val_loss: 0.0386 - val_root_mean_squared_error: 0.2777
# Epoch 211/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.9885e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2794
# Epoch 212/500
# 4/4 [==============================] - 0s 32ms/step - loss: 1.9559e-04 - root_mean_squared_error: 0.0198 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2791
# Epoch 213/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.9719e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.0388 - val_root_mean_squared_error: 0.2785
# Epoch 214/500
# 4/4 [==============================] - 0s 40ms/step - loss: 1.8887e-04 - root_mean_squared_error: 0.0194 - val_loss: 0.0394 - val_root_mean_squared_error: 0.2808
# Epoch 215/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.9572e-04 - root_mean_squared_error: 0.0198 - val_loss: 0.0396 - val_root_mean_squared_error: 0.2814
# Epoch 216/500
# 4/4 [==============================] - 0s 39ms/step - loss: 2.2171e-04 - root_mean_squared_error: 0.0211 - val_loss: 0.0385 - val_root_mean_squared_error: 0.2776
# Epoch 217/500
# 4/4 [==============================] - 0s 37ms/step - loss: 2.5159e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.0392 - val_root_mean_squared_error: 0.2800
# Epoch 218/500
# 4/4 [==============================] - 0s 39ms/step - loss: 2.4343e-04 - root_mean_squared_error: 0.0221 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2831
# Epoch 219/500
# 4/4 [==============================] - 0s 38ms/step - loss: 3.5270e-04 - root_mean_squared_error: 0.0266 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2790
# Epoch 220/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.9808e-04 - root_mean_squared_error: 0.0316 - val_loss: 0.0378 - val_root_mean_squared_error: 0.2751
# Epoch 221/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0010 - root_mean_squared_error: 0.0451 - val_loss: 0.0387 - val_root_mean_squared_error: 0.2781
# Epoch 222/500
# 4/4 [==============================] - 0s 32ms/step - loss: 6.1967e-04 - root_mean_squared_error: 0.0352 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2729
# Epoch 223/500
# 4/4 [==============================] - 0s 41ms/step - loss: 2.9802e-04 - root_mean_squared_error: 0.0244 - val_loss: 0.0356 - val_root_mean_squared_error: 0.2668
# Epoch 224/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.6091e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2748
# Epoch 225/500
# 4/4 [==============================] - 0s 36ms/step - loss: 2.8355e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2794
# Epoch 226/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.5344e-04 - root_mean_squared_error: 0.0301 - val_loss: 0.0371 - val_root_mean_squared_error: 0.2726
# Epoch 227/500
# 4/4 [==============================] - 0s 36ms/step - loss: 8.6251e-04 - root_mean_squared_error: 0.0415 - val_loss: 0.0371 - val_root_mean_squared_error: 0.2723
# Epoch 228/500
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0015 - root_mean_squared_error: 0.0545 - val_loss: 0.0358 - val_root_mean_squared_error: 0.2675
# Epoch 229/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0014 - root_mean_squared_error: 0.0529 - val_loss: 0.0364 - val_root_mean_squared_error: 0.2697
# Epoch 230/500
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0015 - root_mean_squared_error: 0.0556 - val_loss: 0.0359 - val_root_mean_squared_error: 0.2681
# Epoch 231/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0037 - root_mean_squared_error: 0.0861 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2509
# Epoch 232/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0016 - root_mean_squared_error: 0.0559 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2745
# Epoch 233/500
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0022 - root_mean_squared_error: 0.0667 - val_loss: 0.0289 - val_root_mean_squared_error: 0.2404
# Epoch 234/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0013 - root_mean_squared_error: 0.0510 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2540
# Epoch 235/500
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0037 - root_mean_squared_error: 0.0864 - val_loss: 0.0282 - val_root_mean_squared_error: 0.2373
# Epoch 236/500
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0010 - root_mean_squared_error: 0.0457 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2480
# Epoch 237/500
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0015 - root_mean_squared_error: 0.0555 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2509
# Epoch 238/500
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0014 - root_mean_squared_error: 0.0534 - val_loss: 0.0331 - val_root_mean_squared_error: 0.2573
# Epoch 239/500
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0014 - root_mean_squared_error: 0.0521 - val_loss: 0.0304 - val_root_mean_squared_error: 0.2468
# Epoch 240/500
# 4/4 [==============================] - 0s 36ms/step - loss: 5.8885e-04 - root_mean_squared_error: 0.0343 - val_loss: 0.0317 - val_root_mean_squared_error: 0.2518
# Epoch 241/500
# 4/4 [==============================] - 0s 36ms/step - loss: 7.5215e-04 - root_mean_squared_error: 0.0388 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2488
# Epoch 242/500
# 4/4 [==============================] - 0s 33ms/step - loss: 4.0803e-04 - root_mean_squared_error: 0.0286 - val_loss: 0.0317 - val_root_mean_squared_error: 0.2519
# Epoch 243/500
# 4/4 [==============================] - 0s 33ms/step - loss: 5.2614e-04 - root_mean_squared_error: 0.0324 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 244/500
# 4/4 [==============================] - 0s 31ms/step - loss: 3.3336e-04 - root_mean_squared_error: 0.0258 - val_loss: 0.0323 - val_root_mean_squared_error: 0.2542
# Epoch 245/500
# 4/4 [==============================] - 0s 31ms/step - loss: 3.0787e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2522
# Epoch 246/500
# 4/4 [==============================] - 0s 40ms/step - loss: 2.7550e-04 - root_mean_squared_error: 0.0235 - val_loss: 0.0317 - val_root_mean_squared_error: 0.2518
# Epoch 247/500
# 4/4 [==============================] - 0s 40ms/step - loss: 2.8842e-04 - root_mean_squared_error: 0.0240 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2511
# Epoch 248/500
# 4/4 [==============================] - 0s 32ms/step - loss: 2.4249e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2534
# Epoch 249/500
# 4/4 [==============================] - 0s 47ms/step - loss: 2.0966e-04 - root_mean_squared_error: 0.0205 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2520
# Epoch 250/500
# 4/4 [==============================] - 0s 57ms/step - loss: 2.1118e-04 - root_mean_squared_error: 0.0206 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2530
# Epoch 251/500
# 4/4 [==============================] - 0s 81ms/step - loss: 2.0159e-04 - root_mean_squared_error: 0.0201 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2520
# Epoch 252/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.0056e-04 - root_mean_squared_error: 0.0200 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537
# Epoch 253/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.9001e-04 - root_mean_squared_error: 0.0195 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2510
# Epoch 254/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7439e-04 - root_mean_squared_error: 0.0187 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2533
# Epoch 255/500
# 4/4 [==============================] - 0s 37ms/step - loss: 1.7643e-04 - root_mean_squared_error: 0.0188 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2506
# Epoch 256/500
# 4/4 [==============================] - 0s 32ms/step - loss: 1.7283e-04 - root_mean_squared_error: 0.0186 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2535
# Epoch 257/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7351e-04 - root_mean_squared_error: 0.0186 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2500
# Epoch 258/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.6886e-04 - root_mean_squared_error: 0.0184 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537
# Epoch 259/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.6122e-04 - root_mean_squared_error: 0.0180 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 260/500
# 4/4 [==============================] - 0s 38ms/step - loss: 1.5718e-04 - root_mean_squared_error: 0.0177 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537
# Epoch 261/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5902e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2495
# Epoch 262/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.5616e-04 - root_mean_squared_error: 0.0177 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537
# Epoch 263/500
# 4/4 [==============================] - 0s 41ms/step - loss: 1.5080e-04 - root_mean_squared_error: 0.0174 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 264/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.4265e-04 - root_mean_squared_error: 0.0169 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2535
# Epoch 265/500
# 4/4 [==============================] - 0s 32ms/step - loss: 1.2897e-04 - root_mean_squared_error: 0.0161 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2504
# Epoch 266/500
# 4/4 [==============================] - 0s 31ms/step - loss: 1.1899e-04 - root_mean_squared_error: 0.0154 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2531
# Epoch 267/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0641e-04 - root_mean_squared_error: 0.0146 - val_loss: 0.0316 - val_root_mean_squared_error: 0.2515
# Epoch 268/500
# 4/4 [==============================] - 0s 34ms/step - loss: 9.7121e-05 - root_mean_squared_error: 0.0139 - val_loss: 0.0319 - val_root_mean_squared_error: 0.2527
# Epoch 269/500
# 4/4 [==============================] - 0s 35ms/step - loss: 8.9710e-05 - root_mean_squared_error: 0.0134 - val_loss: 0.0319 - val_root_mean_squared_error: 0.2527
# Epoch 270/500
# 4/4 [==============================] - 0s 34ms/step - loss: 8.3141e-05 - root_mean_squared_error: 0.0129 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2523
# Epoch 271/500
# 4/4 [==============================] - 0s 35ms/step - loss: 8.4244e-05 - root_mean_squared_error: 0.0130 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2536
# Epoch 272/500
# 4/4 [==============================] - 0s 32ms/step - loss: 8.1111e-05 - root_mean_squared_error: 0.0127 - val_loss: 0.0319 - val_root_mean_squared_error: 0.2525
# Epoch 273/500
# 4/4 [==============================] - 0s 39ms/step - loss: 8.4684e-05 - root_mean_squared_error: 0.0130 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2533
# Epoch 274/500
# 4/4 [==============================] - 0s 32ms/step - loss: 8.4125e-05 - root_mean_squared_error: 0.0130 - val_loss: 0.0323 - val_root_mean_squared_error: 0.2540
# Epoch 275/500
# 4/4 [==============================] - 0s 41ms/step - loss: 7.9121e-05 - root_mean_squared_error: 0.0126 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2522
# Epoch 276/500
# ...
# Epoch 411/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.7616e-05 - root_mean_squared_error: 0.0059 - val_loss: 0.0324 - val_root_mean_squared_error: 0.2544
# Epoch 412/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7407e-05 - root_mean_squared_error: 0.0059 - val_loss: 0.0321 - val_root_mean_squared_error: 0.2535
# Epoch 413/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.9173e-05 - root_mean_squared_error: 0.0062 - val_loss: 0.0326 - val_root_mean_squared_error: 0.2554
# Epoch 414/500
# 4/4 [==============================] - 0s 37ms/step - loss: 3.3679e-05 - root_mean_squared_error: 0.0082 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2529
# Epoch 415/500
# 4/4 [==============================] - 0s 34ms/step - loss: 4.9339e-05 - root_mean_squared_error: 0.0099 - val_loss: 0.0325 - val_root_mean_squared_error: 0.2548
# Epoch 416/500
# 4/4 [==============================] - 0s 33ms/step - loss: 7.0671e-05 - root_mean_squared_error: 0.0119 - val_loss: 0.0323 - val_root_mean_squared_error: 0.2540
# Epoch 417/500
# 4/4 [==============================] - 0s 33ms/step - loss: 6.3414e-05 - root_mean_squared_error: 0.0113 - val_loss: 0.0319 - val_root_mean_squared_error: 0.2525
# Epoch 418/500
# 4/4 [==============================] - 0s 41ms/step - loss: 6.1028e-05 - root_mean_squared_error: 0.0110 - val_loss: 0.0331 - val_root_mean_squared_error: 0.2571
# Epoch 419/500
# 4/4 [==============================] - 0s 36ms/step - loss: 1.6631e-04 - root_mean_squared_error: 0.0182 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2485
# Epoch 420/500
# 4/4 [==============================] - 0s 36ms/step - loss: 2.8397e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0323 - val_root_mean_squared_error: 0.2542
# Epoch 421/500
# 4/4 [==============================] - 0s 37ms/step - loss: 5.2236e-04 - root_mean_squared_error: 0.0323 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2459
# Epoch 422/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.6815e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2482
# Epoch 423/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.3080e-04 - root_mean_squared_error: 0.0162 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2522
# Epoch 424/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.1803e-04 - root_mean_squared_error: 0.0209 - val_loss: 0.0305 - val_root_mean_squared_error: 0.2469
# Epoch 425/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5865e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2503
# Epoch 426/500
# 4/4 [==============================] - 0s 43ms/step - loss: 9.0216e-05 - root_mean_squared_error: 0.0134 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2457
# Epoch 427/500
# 4/4 [==============================] - 0s 33ms/step - loss: 3.6215e-05 - root_mean_squared_error: 0.0085 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2499
# Epoch 428/500
# 4/4 [==============================] - 0s 40ms/step - loss: 3.4141e-05 - root_mean_squared_error: 0.0083 - val_loss: 0.0307 - val_root_mean_squared_error: 0.2477
# Epoch 429/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.6253e-05 - root_mean_squared_error: 0.0072 - val_loss: 0.0310 - val_root_mean_squared_error: 0.2489
# Epoch 430/500
# 4/4 [==============================] - 0s 33ms/step - loss: 2.4540e-05 - root_mean_squared_error: 0.0070 - val_loss: 0.0304 - val_root_mean_squared_error: 0.2467
# Epoch 431/500
# 4/4 [==============================] - 0s 46ms/step - loss: 4.4444e-05 - root_mean_squared_error: 0.0094 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2500
# Epoch 432/500
# 4/4 [==============================] - 0s 32ms/step - loss: 5.3655e-05 - root_mean_squared_error: 0.0104 - val_loss: 0.0303 - val_root_mean_squared_error: 0.2462
# Epoch 433/500
# 4/4 [==============================] - 0s 39ms/step - loss: 4.0114e-05 - root_mean_squared_error: 0.0090 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2493
# Epoch 434/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.2006e-05 - root_mean_squared_error: 0.0066 - val_loss: 0.0307 - val_root_mean_squared_error: 0.2477
# Epoch 435/500
# 4/4 [==============================] - 0s 36ms/step - loss: 1.5360e-05 - root_mean_squared_error: 0.0055 - val_loss: 0.0310 - val_root_mean_squared_error: 0.2492
# Epoch 436/500
# 4/4 [==============================] - 0s 38ms/step - loss: 1.4847e-05 - root_mean_squared_error: 0.0054 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2480
# Epoch 437/500
# 4/4 [==============================] - 0s 38ms/step - loss: 1.7213e-05 - root_mean_squared_error: 0.0059 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2496
# Epoch 438/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.0223e-05 - root_mean_squared_error: 0.0064 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2481
# Epoch 439/500
# 4/4 [==============================] - 0s 39ms/step - loss: 1.8843e-05 - root_mean_squared_error: 0.0061 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2496
# Epoch 440/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.6916e-05 - root_mean_squared_error: 0.0058 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2485
# Epoch 441/500
# 4/4 [==============================] - 0s 42ms/step - loss: 1.4110e-05 - root_mean_squared_error: 0.0053 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2494
# Epoch 442/500
# 4/4 [==============================] - 0s 40ms/step - loss: 1.2643e-05 - root_mean_squared_error: 0.0050 - val_loss: 0.0310 - val_root_mean_squared_error: 0.2491
# Epoch 443/500
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1794e-05 - root_mean_squared_error: 0.0049 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2495
# Epoch 444/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.1419e-05 - root_mean_squared_error: 0.0048 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2495
# Epoch 445/500
# 4/4 [==============================] - 0s 40ms/step - loss: 1.1076e-05 - root_mean_squared_error: 0.0047 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 446/500
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0900e-05 - root_mean_squared_error: 0.0047 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2497
# Epoch 447/500
# 4/4 [==============================] - 0s 63ms/step - loss: 1.0693e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2498
# Epoch 448/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.0479e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2500
# Epoch 449/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0346e-05 - root_mean_squared_error: 0.0045 - val_loss: 0.0312 - val_root_mean_squared_error: 0.2500
# Epoch 450/500
# 4/4 [==============================] - 0s 42ms/step - loss: 1.0159e-05 - root_mean_squared_error: 0.0045 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2502
# Epoch 451/500
# 4/4 [==============================] - 0s 37ms/step - loss: 1.0047e-05 - root_mean_squared_error: 0.0045 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2502
# Epoch 452/500
# 4/4 [==============================] - 0s 33ms/step - loss: 9.8263e-06 - root_mean_squared_error: 0.0044 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2503
# Epoch 453/500
# 4/4 [==============================] - 0s 38ms/step - loss: 9.6274e-06 - root_mean_squared_error: 0.0044 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2504
# Epoch 454/500
# 4/4 [==============================] - 0s 36ms/step - loss: 9.4682e-06 - root_mean_squared_error: 0.0044 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2504
# Epoch 455/500
# 4/4 [==============================] - 0s 40ms/step - loss: 9.2861e-06 - root_mean_squared_error: 0.0043 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2506
# Epoch 456/500
# 4/4 [==============================] - 0s 41ms/step - loss: 9.2282e-06 - root_mean_squared_error: 0.0043 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2505
# Epoch 457/500
# 4/4 [==============================] - 0s 39ms/step - loss: 9.0517e-06 - root_mean_squared_error: 0.0043 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2507
# Epoch 458/500
# 4/4 [==============================] - 0s 34ms/step - loss: 8.9022e-06 - root_mean_squared_error: 0.0042 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2508
# Epoch 459/500
# 4/4 [==============================] - 0s 33ms/step - loss: 8.7300e-06 - root_mean_squared_error: 0.0042 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2508
# Epoch 460/500
# 4/4 [==============================] - 0s 36ms/step - loss: 8.5307e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2510
# Epoch 461/500
# 4/4 [==============================] - 0s 39ms/step - loss: 8.5947e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2508
# Epoch 462/500
# 4/4 [==============================] - 0s 42ms/step - loss: 8.4856e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2511
# Epoch 463/500
# 4/4 [==============================] - 0s 34ms/step - loss: 8.4472e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2511
# Epoch 464/500
# 4/4 [==============================] - 0s 33ms/step - loss: 8.2137e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2510
# Epoch 465/500
# 4/4 [==============================] - 0s 37ms/step - loss: 7.9303e-06 - root_mean_squared_error: 0.0040 - val_loss: 0.0316 - val_root_mean_squared_error: 0.2514
# Epoch 466/500
# 4/4 [==============================] - 0s 36ms/step - loss: 8.4673e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2509
# Epoch 467/500
# 4/4 [==============================] - 0s 32ms/step - loss: 8.9425e-06 - root_mean_squared_error: 0.0042 - val_loss: 0.0316 - val_root_mean_squared_error: 0.2516
# Epoch 468/500
# 4/4 [==============================] - 0s 40ms/step - loss: 9.7134e-06 - root_mean_squared_error: 0.0044 - val_loss: 0.0316 - val_root_mean_squared_error: 0.2513
# Epoch 469/500
# 4/4 [==============================] - 0s 42ms/step - loss: 9.2253e-06 - root_mean_squared_error: 0.0043 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2511
# Epoch 470/500
# 4/4 [==============================] - 0s 39ms/step - loss: 8.4786e-06 - root_mean_squared_error: 0.0041 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2521
# Epoch 471/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2117e-05 - root_mean_squared_error: 0.0049 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2505
# Epoch 472/500
# 4/4 [==============================] - 0s 36ms/step - loss: 1.8934e-05 - root_mean_squared_error: 0.0062 - val_loss: 0.0318 - val_root_mean_squared_error: 0.2523
# Epoch 473/500
# 4/4 [==============================] - 0s 47ms/step - loss: 2.9213e-05 - root_mean_squared_error: 0.0076 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2511
# Epoch 474/500
# 4/4 [==============================] - 0s 39ms/step - loss: 2.7576e-05 - root_mean_squared_error: 0.0074 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2505
# Epoch 475/500
# 4/4 [==============================] - 0s 35ms/step - loss: 2.4084e-05 - root_mean_squared_error: 0.0069 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2538
# Epoch 476/500
# 4/4 [==============================] - 0s 39ms/step - loss: 6.2020e-05 - root_mean_squared_error: 0.0111 - val_loss: 0.0307 - val_root_mean_squared_error: 0.2478
# Epoch 477/500
# 4/4 [==============================] - 0s 42ms/step - loss: 1.3565e-04 - root_mean_squared_error: 0.0165 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2529
# Epoch 478/500
# 4/4 [==============================] - 0s 38ms/step - loss: 2.7106e-04 - root_mean_squared_error: 0.0233 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2488
# Epoch 479/500
# 4/4 [==============================] - 0s 68ms/step - loss: 2.0580e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.0305 - val_root_mean_squared_error: 0.2468
# Epoch 480/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.9780e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.0329 - val_root_mean_squared_error: 0.2567
# Epoch 481/500
# 4/4 [==============================] - 0s 39ms/step - loss: 5.7264e-04 - root_mean_squared_error: 0.0338 - val_loss: 0.0288 - val_root_mean_squared_error: 0.2400
# Epoch 482/500
# 4/4 [==============================] - 0s 35ms/step - loss: 5.2253e-04 - root_mean_squared_error: 0.0323 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2482
# Epoch 483/500
# 4/4 [==============================] - 0s 46ms/step - loss: 3.9159e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.0297 - val_root_mean_squared_error: 0.2436
# Epoch 484/500
# 4/4 [==============================] - 0s 80ms/step - loss: 1.8561e-04 - root_mean_squared_error: 0.0193 - val_loss: 0.0306 - val_root_mean_squared_error: 0.2474
# Epoch 485/500
# 4/4 [==============================] - 0s 65ms/step - loss: 2.0167e-04 - root_mean_squared_error: 0.0201 - val_loss: 0.0310 - val_root_mean_squared_error: 0.2489
# Epoch 486/500
# 4/4 [==============================] - 0s 33ms/step - loss: 2.6486e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.0295 - val_root_mean_squared_error: 0.2431
# Epoch 487/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0751e-04 - root_mean_squared_error: 0.0147 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2452
# Epoch 488/500
# 4/4 [==============================] - 0s 33ms/step - loss: 1.1690e-04 - root_mean_squared_error: 0.0153 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2509
# Epoch 489/500
# 4/4 [==============================] - 0s 34ms/step - loss: 1.9576e-04 - root_mean_squared_error: 0.0198 - val_loss: 0.0295 - val_root_mean_squared_error: 0.2428
# Epoch 490/500
# 4/4 [==============================] - 0s 35ms/step - loss: 1.2680e-04 - root_mean_squared_error: 0.0159 - val_loss: 0.0298 - val_root_mean_squared_error: 0.2441
# Epoch 491/500
# 4/4 [==============================] - 0s 35ms/step - loss: 4.8201e-05 - root_mean_squared_error: 0.0098 - val_loss: 0.0309 - val_root_mean_squared_error: 0.2486
# Epoch 492/500
# 4/4 [==============================] - 0s 39ms/step - loss: 7.7055e-05 - root_mean_squared_error: 0.0124 - val_loss: 0.0299 - val_root_mean_squared_error: 0.2444
# Epoch 493/500
# 4/4 [==============================] - 0s 35ms/step - loss: 4.8493e-05 - root_mean_squared_error: 0.0098 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2452
# Epoch 494/500
# 4/4 [==============================] - 0s 34ms/step - loss: 2.0085e-05 - root_mean_squared_error: 0.0063 - val_loss: 0.0300 - val_root_mean_squared_error: 0.2448
# Epoch 495/500
# 4/4 [==============================] - 0s 39ms/step - loss: 1.2170e-05 - root_mean_squared_error: 0.0049 - val_loss: 0.0303 - val_root_mean_squared_error: 0.2462
# Epoch 496/500
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3855e-05 - root_mean_squared_error: 0.0053 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2455
# Epoch 497/500
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1713e-05 - root_mean_squared_error: 0.0048 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2460
# Epoch 498/500
# 4/4 [==============================] - 0s 41ms/step - loss: 1.0380e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.0301 - val_root_mean_squared_error: 0.2453
# Epoch 499/500
# 4/4 [==============================] - 0s 39ms/step - loss: 1.2096e-05 - root_mean_squared_error: 0.0049 - val_loss: 0.0303 - val_root_mean_squared_error: 0.2463
# Epoch 500/500
# 4/4 [==============================] - 0s 39ms/step - loss: 1.0782e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.0302 - val_root_mean_squared_error: 0.2459

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def mape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100
  
# make a prediction
yhat = best_model.predict(train_X)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1]*train_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, train_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y = np.concatenate((train_y, train_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Train R-Squared: {r2_score(inv_y, inv_yhat) * 100:.3f}%')
print(f'Train RMSE: {rmse:.3f}')
print(f'Train MAPE: {mape(inv_y, inv_yhat):.3f}%')
# Out:
# 1/1 [==============================] - 1s 896ms/step
# Train R-Squared: 99.908%
# Train RMSE: 0.165
# Train MAPE: 0.580%

# %%
train_result = pd.DataFrame({'train_actual': inv_y, 'train_pred': inv_yhat}, index=reframed.loc[:train_end].index)
train_result
# Out:
#             train_actual  train_pred
# tanggal
# 2011-01-31          17.0   17.033150
# 2011-02-28          17.8   17.299016
# 2011-03-31          16.3   16.777181
# 2011-04-30          18.8   18.574431
# 2011-05-31          20.3   20.240346
# 2011-06-30          16.1   16.168913
# 2011-07-31          16.5   16.319094
# 2011-08-31          15.1   14.985077
# 2011-09-30          16.6   16.680710
# 2011-10-31          19.3   19.247343
# 2011-11-30          22.0   21.956101
# 2011-12-31          20.4   20.449593
# 2012-01-31          21.0   21.049458
# 2012-02-29          21.4   21.435748
# 2012-03-31          22.0   21.972539
# 2012-04-30          26.4   26.268901
# 2012-05-31          26.4   26.445134
# 2012-06-30          30.1   30.015515
# 2012-07-31          27.0   26.948949
# 2012-08-31          26.2   26.097313
# 2012-09-30          29.9   29.873196
# 2012-10-31          30.0   29.951034
# 2012-11-30          31.0   30.900530
# 2012-12-31          11.0   11.040320

# %%
plt.plot(train_result['train_actual'], label='train_actual')
plt.plot(train_result['train_pred'], label='train_pred')
plt.legend()
plt.show()

# %%
# make a prediction
yhat = best_model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1]*test_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Test R-Squared: {round(r2_score(inv_y, inv_yhat) * 100, 2)}%')
print(f'Test RMSE: {round(rmse, 2)}')
print(f'Test MAPE: {round(mape(inv_y, inv_yhat), 2)}%')
# Out:
# 3/3 [==============================] - 0s 7ms/step
# Test R-Squared: 4.44%
# Test RMSE: 9.64
# Test MAPE: 115.49%

# %%
result = pd.DataFrame({'actual': inv_y, 'pred': inv_yhat}, index=reframed.loc[test_start:test_end].index)

# %%
rmse_each_month = []
for index, value in result.iterrows():
    rmse_each_month.append(round(mean_squared_error([value['actual']], [value['pred']], squared=False), 2))
result['rmse'] = rmse_each_month

# %%
mape_each_month = []
for index, value in result.iterrows():
    mape_each_month.append(f"{round(mape([value['actual']], [value['pred']]), 2)}%")
result['mape'] = mape_each_month

# %%
result
# Out:
#             actual       pred   rmse      mape
# tanggal
# 2013-01-31     2.8  13.495688  10.70   381.99%
# 2013-02-28     2.0  17.834876  15.83   791.74%
# 2013-03-31     2.4  21.219566  18.82   784.15%
# 2013-04-30     1.6  26.397114  24.80  1549.82%
# 2013-05-31     2.3  23.857178  21.56   937.27%
# ...            ...        ...    ...       ...
# 2019-08-31    19.7  18.883987   0.82     4.14%
# 2019-09-30    21.6  21.330877   0.27     1.25%
# 2019-10-31    21.6  24.609886   3.01    13.93%
# 2019-11-30    23.5  26.381427   2.88    12.26%
# 2019-12-31    24.3  26.306682   2.01     8.26%
#
# [84 rows x 4 columns]

# %%
plt.plot(result['actual'], label='actual')
plt.plot(result['pred'], label='pred')
plt.legend()
plt.show()
