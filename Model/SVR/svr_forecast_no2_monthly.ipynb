# %%
import matplotlib.pyplot as plt
import pandas as pd
import platform

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Not connected to a GPU

# %%
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# # Monthly

# %%
if platform.system() == 'Windows':
  pm10_monthly = pd.read_csv("..\\Data for model\\no2_meteorolgical_monthly.csv")
elif platform.system() == 'Linux':
  from google.colab import drive
  drive.mount('/content/gdrive')
  pm10_monthly = pd.read_csv("/content/gdrive/Othercomputers/My Laptop (1)/jkt-aqi-forecasting/Model/Data for Model/no2_meteorolgical_monthly.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## NO<sub>2</sub>

# %%
no2_monthly
# Out:
#         tanggal  no2(ug/m3)  no2_ispu  temperatur_rata-rata(°C)  \
# 0    2010-01-31        21.8        14                      27.4
# 1    2010-02-28        28.7        19                      28.2
# 2    2010-03-31        29.2        19                      28.6
# 3    2010-04-30        27.1        18                      29.6
# 4    2010-05-31        31.1        20                      29.3
# ..          ...         ...       ...                       ...
# 115  2019-08-31        25.3        16                      28.3
# 116  2019-09-30        22.5        15                      28.8
# 117  2019-10-31        23.6        15                      29.5
# 118  2019-11-30        24.0        16                      29.5
# 119  2019-12-31        19.9        13                      28.6
#
#      kelembapan_rata-rata(%)  curah_hujan(mm)  kecepatan_angin_rata-rata(m/s)
# 0                       80.2             14.4                             2.5
# 1                       80.3              9.6                             2.6
# 2                       78.5              9.4                             2.6
# 3                       74.5              2.2                             2.7
# 4                       76.7              2.8                             2.7
# ..                       ...              ...                             ...
# 115                     68.8              0.0                             1.4
# 116                     68.9              0.0                             1.2
# 117                     70.0              0.0                             1.2
# 118                     70.8              2.0                             1.3
# 119                     78.6              8.0                             1.4
#
# [120 rows x 7 columns]

# %%
no2_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   tanggal                         120 non-null    object
#  1   no2(ug/m3)                      120 non-null    float64
#  2   no2_ispu                        120 non-null    int64
#  3   temperatur_rata-rata(°C)        120 non-null    float64
#  4   kelembapan_rata-rata(%)         120 non-null    float64
#  5   curah_hujan(mm)                 120 non-null    float64
#  6   kecepatan_angin_rata-rata(m/s)  120 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 6.7+ KB

# %%
no2_monthly['tanggal'] = pd.to_datetime(no2_monthly['tanggal'], dayfirst=True)
no2_monthly.set_index('tanggal', inplace=True)

# %%
no2_monthly.describe()
# Out:
#        no2(ug/m3)    no2_ispu  temperatur_rata-rata(°C)  \
# count  120.000000  120.000000                120.000000
# mean    20.342500   13.441667                 28.484167
# std     10.281407    6.340209                  0.658365
# min      2.700000    3.000000                 26.600000
# 25%      7.500000    5.750000                 28.175000
# 50%     24.050000   16.000000                 28.600000
# 75%     28.925000   19.000000                 28.900000
# max     37.500000   24.000000                 29.900000
#
#        kelembapan_rata-rata(%)  curah_hujan(mm)  \
# count               120.000000       120.000000
# mean                 75.831667         5.907500
# std                   4.315148         5.617263
# min                  66.300000         0.000000
# 25%                  72.750000         1.800000
# 50%                  76.300000         5.050000
# 75%                  78.600000         8.525000
# max                  84.800000        33.000000
#
#        kecepatan_angin_rata-rata(m/s)
# count                      120.000000
# mean                         1.881667
# std                          0.680457
# min                          0.900000
# 25%                          1.300000
# 50%                          1.600000
# 75%                          2.600000
# max                          3.300000

# %%
no2_monthly.corr(method='spearman')
# Out:
#                                 no2(ug/m3)  no2_ispu  \
# no2(ug/m3)                        1.000000  0.995838
# no2_ispu                          0.995838  1.000000
# temperatur_rata-rata(°C)          0.260025  0.255304
# kelembapan_rata-rata(%)          -0.250964 -0.240835
# curah_hujan(mm)                  -0.261007 -0.250228
# kecepatan_angin_rata-rata(m/s)    0.344120  0.345154
#
#                                 temperatur_rata-rata(°C)  \
# no2(ug/m3)                                      0.260025
# no2_ispu                                        0.255304
# temperatur_rata-rata(°C)                        1.000000
# kelembapan_rata-rata(%)                        -0.674751
# curah_hujan(mm)                                -0.598617
# kecepatan_angin_rata-rata(m/s)                 -0.110798
#
#                                 kelembapan_rata-rata(%)  curah_hujan(mm)  \
# no2(ug/m3)                                    -0.250964        -0.261007
# no2_ispu                                      -0.240835        -0.250228
# temperatur_rata-rata(°C)                      -0.674751        -0.598617
# kelembapan_rata-rata(%)                        1.000000         0.845926
# curah_hujan(mm)                                0.845926         1.000000
# kecepatan_angin_rata-rata(m/s)                 0.006361         0.087252
#
#                                 kecepatan_angin_rata-rata(m/s)
# no2(ug/m3)                                            0.344120
# no2_ispu                                              0.345154
# temperatur_rata-rata(°C)                             -0.110798
# kelembapan_rata-rata(%)                               0.006361
# curah_hujan(mm)                                       0.087252
# kecepatan_angin_rata-rata(m/s)                        1.000000

# %% [markdown]
# ### Visualize

# %%
groups = [0, 1, 2, 3, 4, 5]
i = 1
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(no2_monthly.values[:, group])
    plt.title(no2_monthly.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %% [markdown]
# ### Sliding Window

# %%
def series_to_supervised(index, data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    agg.index = index
    if dropnan:
        agg.dropna(inplace=True)
    return agg

values = no2_monthly.values
reframed = series_to_supervised(no2_monthly.index, values, 3, 1)
reframed = reframed.iloc[:, :-5]
reframed
# Out:
#             var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# tanggal
# 2010-04-30       21.8       14.0       27.4       80.2       14.4        2.5
# 2010-05-31       28.7       19.0       28.2       80.3        9.6        2.6
# 2010-06-30       29.2       19.0       28.6       78.5        9.4        2.6
# 2010-07-31       27.1       18.0       29.6       74.5        2.2        2.7
# 2010-08-31       31.1       20.0       29.3       76.7        2.8        2.7
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31       23.1       15.0       29.6       73.6        1.7        1.5
# 2019-09-30       23.8       16.0       29.2       72.1        0.8        1.2
# 2019-10-31       25.3       16.0       28.7       67.9        0.0        1.3
# 2019-11-30       25.3       16.0       28.3       68.8        0.0        1.4
# 2019-12-31       22.5       15.0       28.8       68.9        0.0        1.2
#
#             var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  var5(t-2)  var6(t-2)  \
# tanggal
# 2010-04-30       28.7       19.0       28.2       80.3        9.6        2.6
# 2010-05-31       29.2       19.0       28.6       78.5        9.4        2.6
# 2010-06-30       27.1       18.0       29.6       74.5        2.2        2.7
# 2010-07-31       31.1       20.0       29.3       76.7        2.8        2.7
# 2010-08-31       31.3       20.0       28.8       77.4        5.8        2.6
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31       23.8       16.0       29.2       72.1        0.8        1.2
# 2019-09-30       25.3       16.0       28.7       67.9        0.0        1.3
# 2019-10-31       25.3       16.0       28.3       68.8        0.0        1.4
# 2019-11-30       22.5       15.0       28.8       68.9        0.0        1.2
# 2019-12-31       23.6       15.0       29.5       70.0        0.0        1.2
#
#             var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# tanggal
# 2010-04-30       29.2       19.0       28.6       78.5        9.4        2.6
# 2010-05-31       27.1       18.0       29.6       74.5        2.2        2.7
# 2010-06-30       31.1       20.0       29.3       76.7        2.8        2.7
# 2010-07-31       31.3       20.0       28.8       77.4        5.8        2.6
# 2010-08-31       30.6       20.0       28.3       78.1        7.6        2.6
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31       25.3       16.0       28.7       67.9        0.0        1.3
# 2019-09-30       25.3       16.0       28.3       68.8        0.0        1.4
# 2019-10-31       22.5       15.0       28.8       68.9        0.0        1.2
# 2019-11-30       23.6       15.0       29.5       70.0        0.0        1.2
# 2019-12-31       24.0       16.0       29.5       70.8        2.0        1.3
#
#             var1(t)
# tanggal
# 2010-04-30     27.1
# 2010-05-31     31.1
# 2010-06-30     31.3
# 2010-07-31     30.6
# 2010-08-31     29.2
# ...             ...
# 2019-08-31     25.3
# 2019-09-30     22.5
# 2019-10-31     23.6
# 2019-11-30     24.0
# 2019-12-31     19.9
#
# [117 rows x 19 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
reframed = pd.DataFrame(scaler.fit_transform(reframed), index=reframed.index, columns=reframed.columns)
reframed
# Out:
#             var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# tanggal
# 2010-04-30   0.548851   0.523810   0.242424   0.751351   0.436364   0.666667
# 2010-05-31   0.747126   0.761905   0.484848   0.756757   0.290909   0.708333
# 2010-06-30   0.761494   0.761905   0.606061   0.659459   0.284848   0.708333
# 2010-07-31   0.701149   0.714286   0.909091   0.443243   0.066667   0.750000
# 2010-08-31   0.816092   0.809524   0.818182   0.562162   0.084848   0.750000
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.586207   0.571429   0.909091   0.394595   0.051515   0.250000
# 2019-09-30   0.606322   0.619048   0.787879   0.313514   0.024242   0.125000
# 2019-10-31   0.649425   0.619048   0.636364   0.086486   0.000000   0.166667
# 2019-11-30   0.649425   0.619048   0.515152   0.135135   0.000000   0.208333
# 2019-12-31   0.568966   0.571429   0.666667   0.140541   0.000000   0.125000
#
#             var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  var5(t-2)  var6(t-2)  \
# tanggal
# 2010-04-30   0.747126   0.761905   0.484848   0.756757   0.290909   0.708333
# 2010-05-31   0.761494   0.761905   0.606061   0.659459   0.284848   0.708333
# 2010-06-30   0.701149   0.714286   0.909091   0.443243   0.066667   0.750000
# 2010-07-31   0.816092   0.809524   0.818182   0.562162   0.084848   0.750000
# 2010-08-31   0.821839   0.809524   0.666667   0.600000   0.175758   0.708333
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.606322   0.619048   0.787879   0.313514   0.024242   0.125000
# 2019-09-30   0.649425   0.619048   0.636364   0.086486   0.000000   0.166667
# 2019-10-31   0.649425   0.619048   0.515152   0.135135   0.000000   0.208333
# 2019-11-30   0.568966   0.571429   0.666667   0.140541   0.000000   0.125000
# 2019-12-31   0.600575   0.571429   0.878788   0.200000   0.000000   0.125000
#
#             var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# tanggal
# 2010-04-30   0.761494   0.761905   0.606061   0.659459   0.284848   0.708333
# 2010-05-31   0.701149   0.714286   0.909091   0.443243   0.066667   0.750000
# 2010-06-30   0.816092   0.809524   0.818182   0.562162   0.084848   0.750000
# 2010-07-31   0.821839   0.809524   0.666667   0.600000   0.175758   0.708333
# 2010-08-31   0.801724   0.809524   0.515152   0.637838   0.230303   0.708333
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.649425   0.619048   0.636364   0.086486   0.000000   0.166667
# 2019-09-30   0.649425   0.619048   0.515152   0.135135   0.000000   0.208333
# 2019-10-31   0.568966   0.571429   0.666667   0.140541   0.000000   0.125000
# 2019-11-30   0.600575   0.571429   0.878788   0.200000   0.000000   0.125000
# 2019-12-31   0.612069   0.619048   0.878788   0.243243   0.060606   0.166667
#
#              var1(t)
# tanggal
# 2010-04-30  0.701149
# 2010-05-31  0.816092
# 2010-06-30  0.821839
# 2010-07-31  0.801724
# 2010-08-31  0.761494
# ...              ...
# 2019-08-31  0.649425
# 2019-09-30  0.568966
# 2019-10-31  0.600575
# 2019-11-30  0.612069
# 2019-12-31  0.494253
#
# [117 rows x 19 columns]

# %%
from datetime import datetime

train_end = datetime.strptime('2016-12-31', '%Y-%m-%d')
test_start = datetime.strptime('2017-01-01', '%Y-%m-%d')
test_end = datetime.strptime('2019-12-31', '%Y-%m-%d')

train = reframed.loc[:train_end].values
test = reframed.loc[test_start:test_end].values
train_X, train_y = train[:, :-1], train[:, -1:]
test_X, test_y = test[:, :-1], test[:, -1:]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (81, 18) (81, 1) (36, 18) (36, 1)

# %%
# !pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.8/dist-packages (1.1.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.21.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (7.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (5.7.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->keras_tuner) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (4.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.19.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (2.15.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras_tuner) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (6.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.2)

# %%
from sklearn.svm import SVR
import keras_tuner as kt

def call_existing_code(kernel, degree, gamma, coef0, tol, C, epsilon, shrinking):
    model = SVR(
        kernel=kernel,
        degree=degree, # poly
        gamma=gamma, # rbf, poly
        coef0=coef0, # poly
        tol=tol,
        C=C,
        epsilon=epsilon,
        shrinking=shrinking
    )
    return model

def build_model(hp):
    kernel = hp.Choice("kernel", ["poly", "rbf", "linear"], default="rbf")
    degree = hp.Int("degree", min_value=1, max_value=10, step=1, default=3)
    gamma = hp.Choice("gamma", ["scale", "auto"], default="scale")
    # gamma = hp.Choice("gamma", [1.0, 0.1, 0.01, 0.001, 0.0001])
    coef0 = hp.Float("coef0", min_value=0.0, max_value=1.0, step=0.1, default=0.0)
    tol = hp.Float("tol", min_value=1e-4, max_value=1e-2, default=1e-3)
    C = hp.Choice("C", [0.1, 1.0, 10.0, 100.0, 1000.0], default=1.0)
    epsilon = hp.Float("epsilon", min_value=1e-3, max_value=1.0, default=1e-1)
    shrinking = hp.Boolean("shrinking", default=True)
    model = call_existing_code(
        kernel=kernel,
        degree=degree,
        gamma=gamma,
        coef0=coef0,
        tol=tol,
        C=C,
        epsilon=epsilon,
        shrinking=shrinking
    )
    return model

build_model(kt.HyperParameters())
# Out:
# SVR()

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

if platform.system() == 'Windows':
  tuner = kt.tuners.SklearnTuner(
      oracle=kt.oracles.BayesianOptimizationOracle(
          objective=kt.Objective('score', 'max'),
          max_trials=100
      ),
    hypermodel=build_model,
    scoring=make_scorer(mean_squared_error, greater_is_better=False, squared=False),
    cv=TimeSeriesSplit(),
    overwrite=False,
    directory="D:\\From External Drive\\Kuliah\\Tugas Akhir\\undergraduate-thesis_2.0\\data-and-model\\Model",
    project_name="svr_no2_monthly_80-20_result"
  )
elif platform.system() == 'Linux':
  tuner = kt.tuners.SklearnTuner(
      oracle=kt.oracles.BayesianOptimizationOracle(
          objective=kt.Objective('score', 'max'),
          max_trials=100
      ),
    hypermodel=build_model,
    scoring=make_scorer(mean_squared_error, greater_is_better=False, squared=False),
    cv=TimeSeriesSplit(),
    overwrite=False,
    directory="/content/drive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model",
    project_name="svr_no2_monthly_80-20_result"
    )

tuner.search(train_X, train_y)

# %%
tuner.results_summary(num_trials=100)
# Out:
# Results summary
# Results in /content/drive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model/svr_no2_monthly_80-20_result
# Showing 100 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fb150290e50>
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: auto
# coef0: 0.30000000000000004
# tol: 0.006011044892249652
# C: 1.0
# epsilon: 0.027107066878028937
# shrinking: True
# Score: -0.16100366533083216
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.5
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.6000000000000001
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.8
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16391195015165136
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: auto
# coef0: 0.2
# tol: 0.004172599560779101
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.1640913782446302
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.0
# tol: 0.003545753342945706
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16419878806832355
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.30000000000000004
# tol: 0.0035228407962736774
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16419878806832355
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.0
# tol: 0.005022696991939993
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16437471948468435
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 3
# gamma: auto
# coef0: 0.1
# tol: 0.006425239336715576
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: auto
# coef0: 0.2
# tol: 0.007483932266589432
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.2
# tol: 0.007464881313586011
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 2
# gamma: auto
# coef0: 0.2
# tol: 0.007458618336285649
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.2
# tol: 0.007732365387341663
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.0
# tol: 0.006501382049704295
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.007148355627301824
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.4
# tol: 0.006787941681068775
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16446289486249732
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: scale
# coef0: 0.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16460218646413347
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: auto
# coef0: 0.4
# tol: 0.005345661448135574
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.1647713830866227
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.2
# tol: 0.008136220694127574
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008132586506404402
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008757122893783503
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008773628266910806
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008769600637964718
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008701429460889237
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008763021688206848
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008774803158454199
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.00878319080851289
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008782847732184447
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.0087790506476544
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.00876326107141835
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008056006711528584
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008760635658002244
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.1
# tol: 0.008341948833216737
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16488126709042356
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: auto
# coef0: 0.1
# tol: 0.005992913300669883
# C: 1.0
# epsilon: 0.001
# shrinking: True
# Score: -0.167687641714635
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: auto
# coef0: 0.2
# tol: 0.00604785196339718
# C: 1.0
# epsilon: 0.001
# shrinking: True
# Score: -0.167687641714635
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: auto
# coef0: 0.4
# tol: 0.006102097918538348
# C: 1.0
# epsilon: 0.001
# shrinking: True
# Score: -0.16847655513838458
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: auto
# coef0: 0.2
# tol: 0.005929075544824013
# C: 0.1
# epsilon: 0.11038342059761672
# shrinking: True
# Score: -0.18207951469611822
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 9
# gamma: scale
# coef0: 0.4
# tol: 0.0009055506405252637
# C: 1.0
# epsilon: 0.2166571967599161
# shrinking: True
# Score: -0.21943405380218167
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: auto
# coef0: 0.30000000000000004
# tol: 0.009616843018676111
# C: 0.1
# epsilon: 0.32057809317729596
# shrinking: False
# Score: -0.2336020425568673
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 4
# gamma: scale
# coef0: 1.0
# tol: 0.0016136979422307694
# C: 1.0
# epsilon: 0.39783873436892847
# shrinking: False
# Score: -0.24819600182924778
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 4
# gamma: scale
# coef0: 0.7000000000000001
# tol: 0.008773003417172203
# C: 0.1
# epsilon: 0.40348484065458806
# shrinking: True
# Score: -0.24895600037477345
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 1
# gamma: auto
# coef0: 0.6000000000000001
# tol: 0.0007924817037104208
# C: 100.0
# epsilon: 0.44014750483233234
# shrinking: False
# Score: -0.25199112136529545
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 10
# gamma: auto
# coef0: 0.6000000000000001
# tol: 0.007592806029869231
# C: 0.1
# epsilon: 0.13262296959337283
# shrinking: True
# Score: -0.2524460021497369
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 2
# gamma: scale
# coef0: 0.8
# tol: 0.009125208171058441
# C: 0.1
# epsilon: 0.4535402077227659
# shrinking: False
# Score: -0.25796110142561174
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 3
# gamma: auto
# coef0: 0.9
# tol: 0.007742680753120676
# C: 0.1
# epsilon: 0.9830775183996254
# shrinking: True
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 5
# gamma: scale
# coef0: 0.4
# tol: 0.00886523082180657
# C: 1.0
# epsilon: 0.5973040127255207
# shrinking: False
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 2
# gamma: scale
# coef0: 0.30000000000000004
# tol: 0.0026987244799265516
# C: 0.1
# epsilon: 0.821970727086067
# shrinking: False
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 6
# gamma: auto
# coef0: 0.2
# tol: 0.0007498545087802719
# C: 0.1
# epsilon: 0.8418521951312219
# shrinking: True
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 4
# gamma: scale
# coef0: 0.9
# tol: 0.006005023355678096
# C: 1.0
# epsilon: 0.8465503085178565
# shrinking: False
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 3
# gamma: auto
# coef0: 0.6000000000000001
# tol: 0.0032414517045111437
# C: 100.0
# epsilon: 0.6693516291037067
# shrinking: True
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 1
# gamma: scale
# coef0: 0.8
# tol: 0.009725558163610232
# C: 0.1
# epsilon: 0.9529922315575305
# shrinking: True
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 2
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.00664269567660239
# C: 1000.0
# epsilon: 0.7261753916854174
# shrinking: True
# Score: -0.25953426467870705
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.0032496717031490012
# C: 1000.0
# epsilon: 0.5404940569266922
# shrinking: False
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 5
# gamma: scale
# coef0: 0.1
# tol: 0.001297085300335079
# C: 1000.0
# epsilon: 0.624191374554968
# shrinking: False
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 8
# gamma: auto
# coef0: 0.2
# tol: 0.0027095718046313846
# C: 10.0
# epsilon: 0.9428814072511414
# shrinking: False
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 7
# gamma: scale
# coef0: 0.5
# tol: 0.008650131076309589
# C: 1000.0
# epsilon: 0.9837291769825492
# shrinking: True
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 3
# gamma: auto
# coef0: 0.2
# tol: 0.003869451062755343
# C: 10.0
# epsilon: 0.6603333240344235
# shrinking: True
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 10
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.005007901948439512
# C: 1.0
# epsilon: 0.9212155279507316
# shrinking: True
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 3
# gamma: scale
# coef0: 0.0
# tol: 0.005125374126671957
# C: 0.1
# epsilon: 0.7643010009797319
# shrinking: True
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 9
# gamma: scale
# coef0: 0.5
# tol: 0.00483011370030816
# C: 1000.0
# epsilon: 0.6410114008113416
# shrinking: False
# Score: -0.2595342646787071
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 1
# gamma: auto
# coef0: 0.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.2747436562469197
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.01
# C: 1000.0
# epsilon: 0.001
# shrinking: True
# Score: -0.2931070376517215

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model
# Out:
# SVR(coef0=0.30000000000000004, degree=6, epsilon=0.027107066878028937,
#     gamma='auto', kernel='linear', tol=0.006011044892249652)

# %%
import numpy as np

best_hps = tuner.get_best_hyperparameters(10)
best_model = build_model(best_hps[0])
best_model.fit(train_X, train_y)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(coef0=0.30000000000000004, degree=6, epsilon=0.027107066878028937,
#     gamma='auto', kernel='linear', tol=0.006011044892249652)

# %%
train_y = train_y.reshape((len(train_y), 1))
inv_y = np.concatenate((train_y, train_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

pred = best_model.predict(train_X)
pred = pred.reshape((len(pred), 1))
inv_yhat = np.concatenate((pred, train_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

train_result = pd.DataFrame({'actual': inv_y, 'pred': inv_yhat}, index=reframed.loc[:train_end].index)

# %%
plt.plot(train_result['actual'], label='train_actual')
plt.plot(train_result['pred'], label='train_pred')
plt.legend()
plt.show()

# %%
def mape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
from sklearn.metrics import r2_score

rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Train R-Squared: {r2_score(inv_y, inv_yhat) * 100:.3f}%')
print(f'Train RMSE: {rmse:.3f}')
print(f'Train MAPE: {mape(inv_y, inv_yhat):.3f}%')
# Out:
# Train R-Squared: 76.910%
# Train RMSE: 4.299
# Train MAPE: 20.538%

# %%
rmse_each_month = []
for index, value in train_result.iterrows():
    rmse_each_month.append(round(mean_squared_error([value['actual']], [value['pred']], squared=False), 2))
train_result['rmse'] = rmse_each_month

# %%
mape_each_month = []
for index, value in train_result.iterrows():
    mape_each_month.append(f"{round(mape([value['actual']], [value['pred']]), 2)}%")
train_result['mape'] = mape_each_month

# %%
train_result
# Out:
#             actual       pred  rmse     mape
# tanggal
# 2010-04-30    27.1  31.104292  4.00   14.78%
# 2010-05-31    31.1  28.388772  2.71    8.72%
# 2010-06-30    31.3  29.618161  1.68    5.37%
# 2010-07-31    30.6  28.659534  1.94    6.34%
# 2010-08-31    29.2  30.226243  1.03    3.51%
# ...            ...        ...   ...      ...
# 2016-08-31     5.6   5.510082  0.09    1.61%
# 2016-09-30     5.0   5.735181  0.74    14.7%
# 2016-10-31     6.0   5.793099  0.21    3.45%
# 2016-11-30     6.0   4.939166  1.06   17.68%
# 2016-12-31     2.7   5.730376  3.03  112.24%
#
# [81 rows x 4 columns]

# %%
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

pred = best_model.predict(test_X)
pred = pred.reshape((len(pred), 1))
inv_yhat = np.concatenate((pred, test_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

test_result = pd.DataFrame({'actual': inv_y, 'pred': inv_yhat}, index=reframed.loc[test_start:test_end].index)

# %%
plt.plot(test_result['actual'], label='test_actual')
plt.plot(test_result['pred'], label='test_pred')
plt.legend()
plt.show()

# %%
rmse_each_month = []
for index, value in test_result.iterrows():
    rmse_each_month.append(round(mean_squared_error([value['actual']], [value['pred']], squared=False), 2))
test_result['rmse'] = rmse_each_month

# %%
mape_each_month = []
for index, value in test_result.iterrows():
    mape_each_month.append(f"{round(mape([value['actual']], [value['pred']]), 2)}%")
test_result['mape'] = mape_each_month

# %%
rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Test R-Squared: {r2_score(inv_y, inv_yhat) * 100:.3f}%')
print(f'Test RMSE: {rmse:.3f}')
print(f'Test MAPE: {mape(inv_y, inv_yhat):.3f}%')
# Out:
# Test R-Squared: 78.277%
# Test RMSE: 3.662
# Test MAPE: 25.201%

# %%
test_result
# Out:
#             actual       pred   rmse    mape
# tanggal
# 2017-01-31     3.2   4.557368   1.36  42.42%
# 2017-02-28     5.7   7.408134   1.71  29.97%
# 2017-03-31     6.8   6.003491   0.80  11.71%
# 2017-04-30     7.2   5.607281   1.59  22.12%
# 2017-05-31     8.4  10.133480   1.73  20.64%
# 2017-06-30     6.1   8.396349   2.30  37.65%
# 2017-07-31     8.7   6.007414   2.69  30.95%
# 2017-08-31     8.5   7.263526   1.24  14.55%
# 2017-09-30     8.6   9.933906   1.33  15.51%
# 2017-10-31     8.4  11.147750   2.75  32.71%
# 2017-11-30     7.6   3.818813   3.78  49.75%
# 2017-12-31     4.8   5.177905   0.38   7.87%
# 2018-01-31     4.4   5.665081   1.27  28.75%
# 2018-02-28     5.5   7.488797   1.99  36.16%
# 2018-03-31     6.0   8.545659   2.55  42.43%
# 2018-04-30     5.4   4.035540   1.36  25.27%
# 2018-05-31     7.0   9.012654   2.01  28.75%
# 2018-06-30     5.8   6.515700   0.72  12.34%
# 2018-07-31     5.6   5.607529   0.01   0.13%
# 2018-08-31     5.3   4.828205   0.47    8.9%
# 2018-09-30     6.9   9.530591   2.63  38.12%
# 2018-10-31     6.2   6.695159   0.50   7.99%
# 2018-11-30     4.8   5.956298   1.16  24.09%
# 2018-12-31     5.7  -0.045795   5.75  100.8%
# 2019-01-31    15.0   0.546962  14.45  96.35%
# 2019-02-28    19.6  14.972877   4.63  23.61%
# 2019-03-31    22.5  12.752677   9.75  43.32%
# 2019-04-30    24.9  24.058547   0.84   3.38%
# 2019-05-31    23.1  24.318964   1.22   5.28%
# 2019-06-30    23.8  22.032883   1.77   7.42%
# 2019-07-31    25.3  24.231905   1.07   4.22%
# 2019-08-31    25.3  23.697713   1.60   6.33%
# 2019-09-30    22.5  25.237672   2.74  12.17%
# 2019-10-31    23.6  21.079430   2.52  10.68%
# 2019-11-30    24.0  19.012271   4.99  20.78%
# 2019-12-31    19.9  19.085766   0.81   4.09%
