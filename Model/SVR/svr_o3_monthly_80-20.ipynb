# %%
import matplotlib.pyplot as plt
import pandas as pd
import platform

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Not connected to a GPU

# %%
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# # Monthly

# %%
if platform.system() == 'Windows':
  pm10_monthly = pd.read_csv("..\\Data for model\\o3_meteorolgical_monthly.csv")
elif platform.system() == 'Linux':
  from google.colab import drive
  drive.mount('/content/gdrive')
  pm10_monthly = pd.read_csv("/content/gdrive/Othercomputers/My Laptop (1)/jkt-aqi-forecasting/Model/Data for Model/o3_meteorolgical_monthly.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## O<sub>3</sub>

# %%
o3_monthly
# Out:
#         tanggal  o3(ug/m3)  o3_ispu  temperatur_rata-rata(°C)  \
# 0    2010-01-31       51.0       22                      27.4
# 1    2010-02-28       97.1       41                      28.2
# 2    2010-03-31      101.1       42                      28.6
# 3    2010-04-30      118.3       49                      29.6
# 4    2010-05-31      124.3       52                      29.3
# ..          ...        ...      ...                       ...
# 115  2019-08-31      143.1       60                      28.3
# 116  2019-09-30      140.4       59                      28.8
# 117  2019-10-31      159.5       67                      29.5
# 118  2019-11-30      162.7       69                      29.5
# 119  2019-12-31      123.3       51                      28.6
#
#      kelembapan_rata-rata(%)  curah_hujan(mm)  kecepatan_angin_rata-rata(m/s)
# 0                       80.2             14.4                             2.5
# 1                       80.3              9.6                             2.6
# 2                       78.5              9.4                             2.6
# 3                       74.5              2.2                             2.7
# 4                       76.7              2.8                             2.7
# ..                       ...              ...                             ...
# 115                     68.8              0.0                             1.4
# 116                     68.9              0.0                             1.2
# 117                     70.0              0.0                             1.2
# 118                     70.8              2.0                             1.3
# 119                     78.6              8.0                             1.4
#
# [120 rows x 7 columns]

# %%
o3_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   tanggal                         120 non-null    object
#  1   o3(ug/m3)                       120 non-null    float64
#  2   o3_ispu                         120 non-null    int64
#  3   temperatur_rata-rata(°C)        120 non-null    float64
#  4   kelembapan_rata-rata(%)         120 non-null    float64
#  5   curah_hujan(mm)                 120 non-null    float64
#  6   kecepatan_angin_rata-rata(m/s)  120 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 6.7+ KB

# %%
o3_monthly['tanggal'] = pd.to_datetime(o3_monthly['tanggal'], dayfirst=True)
o3_monthly.set_index('tanggal', inplace=True)

# %%
o3_monthly.describe()
# Out:
#         o3(ug/m3)     o3_ispu  temperatur_rata-rata(°C)  \
# count  120.000000  120.000000                120.000000
# mean   123.872500   52.133333                 28.484167
# std     40.796987   17.162071                  0.658365
# min     31.100000   14.000000                 26.600000
# 25%     95.125000   40.000000                 28.175000
# 50%    126.200000   52.500000                 28.600000
# 75%    156.550000   66.000000                 28.900000
# max    203.900000   86.000000                 29.900000
#
#        kelembapan_rata-rata(%)  curah_hujan(mm)  \
# count               120.000000       120.000000
# mean                 75.831667         5.907500
# std                   4.315148         5.617263
# min                  66.300000         0.000000
# 25%                  72.750000         1.800000
# 50%                  76.300000         5.050000
# 75%                  78.600000         8.525000
# max                  84.800000        33.000000
#
#        kecepatan_angin_rata-rata(m/s)
# count                      120.000000
# mean                         1.881667
# std                          0.680457
# min                          0.900000
# 25%                          1.300000
# 50%                          1.600000
# 75%                          2.600000
# max                          3.300000

# %%
o3_monthly.corr(method='spearman')
# Out:
#                                 o3(ug/m3)   o3_ispu  temperatur_rata-rata(°C)  \
# o3(ug/m3)                        1.000000  0.999715                  0.314346
# o3_ispu                          0.999715  1.000000                  0.314866
# temperatur_rata-rata(°C)         0.314346  0.314866                  1.000000
# kelembapan_rata-rata(%)         -0.331460 -0.331565                 -0.674751
# curah_hujan(mm)                 -0.274015 -0.275958                 -0.598617
# kecepatan_angin_rata-rata(m/s)   0.319836  0.316290                 -0.110798
#
#                                 kelembapan_rata-rata(%)  curah_hujan(mm)  \
# o3(ug/m3)                                     -0.331460        -0.274015
# o3_ispu                                       -0.331565        -0.275958
# temperatur_rata-rata(°C)                      -0.674751        -0.598617
# kelembapan_rata-rata(%)                        1.000000         0.845926
# curah_hujan(mm)                                0.845926         1.000000
# kecepatan_angin_rata-rata(m/s)                 0.006361         0.087252
#
#                                 kecepatan_angin_rata-rata(m/s)
# o3(ug/m3)                                             0.319836
# o3_ispu                                               0.316290
# temperatur_rata-rata(°C)                             -0.110798
# kelembapan_rata-rata(%)                               0.006361
# curah_hujan(mm)                                       0.087252
# kecepatan_angin_rata-rata(m/s)                        1.000000

# %% [markdown]
# ### Visualize

# %%
groups = [0, 1, 2, 3, 4, 5]
i = 1
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(o3_monthly.values[:, group])
    plt.title(o3_monthly.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %% [markdown]
# ### Sliding Window

# %%
def series_to_supervised(index, data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    agg.index = index
    if dropnan:
        agg.dropna(inplace=True)
    return agg

values = o3_monthly.values
reframed = series_to_supervised(o3_monthly.index, values, 3, 1)
reframed = reframed.iloc[:, :-5]
reframed
# Out:
#             var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# tanggal
# 2010-04-30       51.0       22.0       27.4       80.2       14.4        2.5
# 2010-05-31       97.1       41.0       28.2       80.3        9.6        2.6
# 2010-06-30      101.1       42.0       28.6       78.5        9.4        2.6
# 2010-07-31      118.3       49.0       29.6       74.5        2.2        2.7
# 2010-08-31      124.3       52.0       29.3       76.7        2.8        2.7
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31      120.6       50.0       29.6       73.6        1.7        1.5
# 2019-09-30      149.9       63.0       29.2       72.1        0.8        1.2
# 2019-10-31      131.7       55.0       28.7       67.9        0.0        1.3
# 2019-11-30      143.1       60.0       28.3       68.8        0.0        1.4
# 2019-12-31      140.4       59.0       28.8       68.9        0.0        1.2
#
#             var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  var5(t-2)  var6(t-2)  \
# tanggal
# 2010-04-30       97.1       41.0       28.2       80.3        9.6        2.6
# 2010-05-31      101.1       42.0       28.6       78.5        9.4        2.6
# 2010-06-30      118.3       49.0       29.6       74.5        2.2        2.7
# 2010-07-31      124.3       52.0       29.3       76.7        2.8        2.7
# 2010-08-31      102.4       43.0       28.8       77.4        5.8        2.6
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31      149.9       63.0       29.2       72.1        0.8        1.2
# 2019-09-30      131.7       55.0       28.7       67.9        0.0        1.3
# 2019-10-31      143.1       60.0       28.3       68.8        0.0        1.4
# 2019-11-30      140.4       59.0       28.8       68.9        0.0        1.2
# 2019-12-31      159.5       67.0       29.5       70.0        0.0        1.2
#
#             var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# tanggal
# 2010-04-30      101.1       42.0       28.6       78.5        9.4        2.6
# 2010-05-31      118.3       49.0       29.6       74.5        2.2        2.7
# 2010-06-30      124.3       52.0       29.3       76.7        2.8        2.7
# 2010-07-31      102.4       43.0       28.8       77.4        5.8        2.6
# 2010-08-31      102.3       43.0       28.3       78.1        7.6        2.6
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31      131.7       55.0       28.7       67.9        0.0        1.3
# 2019-09-30      143.1       60.0       28.3       68.8        0.0        1.4
# 2019-10-31      140.4       59.0       28.8       68.9        0.0        1.2
# 2019-11-30      159.5       67.0       29.5       70.0        0.0        1.2
# 2019-12-31      162.7       69.0       29.5       70.8        2.0        1.3
#
#             var1(t)
# tanggal
# 2010-04-30    118.3
# 2010-05-31    124.3
# 2010-06-30    102.4
# 2010-07-31    102.3
# 2010-08-31    115.5
# ...             ...
# 2019-08-31    143.1
# 2019-09-30    140.4
# 2019-10-31    159.5
# 2019-11-30    162.7
# 2019-12-31    123.3
#
# [117 rows x 19 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
reframed = pd.DataFrame(scaler.fit_transform(reframed), index=reframed.index, columns=reframed.columns)
reframed
# Out:
#             var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# tanggal
# 2010-04-30   0.115162   0.111111   0.242424   0.751351   0.436364   0.666667
# 2010-05-31   0.381944   0.375000   0.484848   0.756757   0.290909   0.708333
# 2010-06-30   0.405093   0.388889   0.606061   0.659459   0.284848   0.708333
# 2010-07-31   0.504630   0.486111   0.909091   0.443243   0.066667   0.750000
# 2010-08-31   0.539352   0.527778   0.818182   0.562162   0.084848   0.750000
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.517940   0.500000   0.909091   0.394595   0.051515   0.250000
# 2019-09-30   0.687500   0.680556   0.787879   0.313514   0.024242   0.125000
# 2019-10-31   0.582176   0.569444   0.636364   0.086486   0.000000   0.166667
# 2019-11-30   0.648148   0.638889   0.515152   0.135135   0.000000   0.208333
# 2019-12-31   0.632523   0.625000   0.666667   0.140541   0.000000   0.125000
#
#             var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  var5(t-2)  var6(t-2)  \
# tanggal
# 2010-04-30   0.381944   0.375000   0.484848   0.756757   0.290909   0.708333
# 2010-05-31   0.405093   0.388889   0.606061   0.659459   0.284848   0.708333
# 2010-06-30   0.504630   0.486111   0.909091   0.443243   0.066667   0.750000
# 2010-07-31   0.539352   0.527778   0.818182   0.562162   0.084848   0.750000
# 2010-08-31   0.412616   0.402778   0.666667   0.600000   0.175758   0.708333
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.687500   0.680556   0.787879   0.313514   0.024242   0.125000
# 2019-09-30   0.582176   0.569444   0.636364   0.086486   0.000000   0.166667
# 2019-10-31   0.648148   0.638889   0.515152   0.135135   0.000000   0.208333
# 2019-11-30   0.632523   0.625000   0.666667   0.140541   0.000000   0.125000
# 2019-12-31   0.743056   0.736111   0.878788   0.200000   0.000000   0.125000
#
#             var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# tanggal
# 2010-04-30   0.405093   0.388889   0.606061   0.659459   0.284848   0.708333
# 2010-05-31   0.504630   0.486111   0.909091   0.443243   0.066667   0.750000
# 2010-06-30   0.539352   0.527778   0.818182   0.562162   0.084848   0.750000
# 2010-07-31   0.412616   0.402778   0.666667   0.600000   0.175758   0.708333
# 2010-08-31   0.412037   0.402778   0.515152   0.637838   0.230303   0.708333
# ...               ...        ...        ...        ...        ...        ...
# 2019-08-31   0.582176   0.569444   0.636364   0.086486   0.000000   0.166667
# 2019-09-30   0.648148   0.638889   0.515152   0.135135   0.000000   0.208333
# 2019-10-31   0.632523   0.625000   0.666667   0.140541   0.000000   0.125000
# 2019-11-30   0.743056   0.736111   0.878788   0.200000   0.000000   0.125000
# 2019-12-31   0.761574   0.763889   0.878788   0.243243   0.060606   0.166667
#
#              var1(t)
# tanggal
# 2010-04-30  0.504630
# 2010-05-31  0.539352
# 2010-06-30  0.412616
# 2010-07-31  0.412037
# 2010-08-31  0.488426
# ...              ...
# 2019-08-31  0.648148
# 2019-09-30  0.632523
# 2019-10-31  0.743056
# 2019-11-30  0.761574
# 2019-12-31  0.533565
#
# [117 rows x 19 columns]

# %%
from datetime import datetime

train_end = datetime.strptime('2011-12-31', '%Y-%m-%d')
test_start = datetime.strptime('2012-01-01', '%Y-%m-%d')
test_end = datetime.strptime('2019-12-31', '%Y-%m-%d')

train = reframed.loc[:train_end].values
test = reframed.loc[test_start:test_end].values
train_X, train_y = train[:, :-1], train[:, -1:]
test_X, test_y = test[:, :-1], test[:, -1:]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (21, 18) (21, 1) (96, 18) (96, 1)

# %%
# !pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.8/dist-packages (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.25.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (2.9.1)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (1.0.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras_tuner) (7.9.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->keras_tuner) (0.18.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->keras_tuner) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras_tuner) (4.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.51.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.19.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras_tuner) (0.38.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras_tuner) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (6.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.2)

# %%
from sklearn.svm import SVR
import keras_tuner as kt

def call_existing_code(kernel, degree, gamma, coef0, tol, C, epsilon, shrinking):
    model = SVR(
        kernel=kernel,
        degree=degree, # poly
        gamma=gamma, # rbf, poly
        coef0=coef0, # poly
        tol=tol,
        C=C,
        epsilon=epsilon,
        shrinking=shrinking
    )
    return model

def build_model(hp):
    kernel = hp.Choice("kernel", ["poly", "rbf", "linear"], default="rbf")
    degree = hp.Int("degree", min_value=1, max_value=10, step=1, default=3)
    gamma = hp.Choice("gamma", ["scale", "auto"], default="scale")
    # gamma = hp.Choice("gamma", [1.0, 0.1, 0.01, 0.001, 0.0001])
    coef0 = hp.Float("coef0", min_value=0.0, max_value=1.0, step=0.1, default=0.0)
    tol = hp.Float("tol", min_value=1e-4, max_value=1e-2, default=1e-3)
    C = hp.Choice("C", [0.1, 1.0, 10.0, 100.0, 1000.0], default=1.0)
    epsilon = hp.Float("epsilon", min_value=1e-3, max_value=1.0, default=1e-1)
    shrinking = hp.Boolean("shrinking", default=True)
    model = call_existing_code(
        kernel=kernel,
        degree=degree,
        gamma=gamma,
        coef0=coef0,
        tol=tol,
        C=C,
        epsilon=epsilon,
        shrinking=shrinking
    )
    return model

build_model(kt.HyperParameters())
# Out:
# SVR()

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

if platform.system() == 'Windows':
  tuner = kt.tuners.SklearnTuner(
      oracle=kt.oracles.BayesianOptimizationOracle(
          objective=kt.Objective('score', 'max'),
          max_trials=100
      ),
    hypermodel=build_model,
    scoring=make_scorer(mean_squared_error, greater_is_better=False, squared=False),
    cv=TimeSeriesSplit(),
    overwrite=False,
    directory="D:\\From External Drive\\Kuliah\\Tugas Akhir\\undergraduate-thesis_2.0\\data-and-model\\Model",
    project_name="svr_o3_monthly_80-20_result"
  )
elif platform.system() == 'Linux':
  tuner = kt.tuners.SklearnTuner(
      oracle=kt.oracles.BayesianOptimizationOracle(
          objective=kt.Objective('score', 'max'),
          max_trials=100
      ),
    hypermodel=build_model,
    scoring=make_scorer(mean_squared_error, greater_is_better=False, squared=False),
    cv=TimeSeriesSplit(),
    overwrite=False,
    directory="/content/drive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model",
    project_name="svr_o3_monthly_80-20_result"
    )

tuner.search(train_X, train_y)

# %%
tuner.results_summary(num_trials=100)
# Out:
# Results summary
# Results in /content/drive/Othercomputers/My Laptop (1)/undergraduate-thesis_2.0/data-and-model/Model/svr_o3_monthly_80-20_result
# Showing 100 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fd31f93b880>
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: scale
# coef0: 0.30000000000000004
# tol: 0.0006266295958271196
# C: 1.0
# epsilon: 0.09061434370161621
# shrinking: False
# Score: -0.1602117274729583
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.5
# tol: 0.007089657603069828
# C: 1.0
# epsilon: 0.019181529364727463
# shrinking: False
# Score: -0.16090150564809622
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.004649719493227994
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.164937137708894
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 3
# gamma: scale
# coef0: 0.30000000000000004
# tol: 0.004396258056206524
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16495717161379553
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.6000000000000001
# tol: 0.004449369578672671
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16495717161379553
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.004024611710510973
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16495717161379553
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.004876336851826517
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.1649684602558496
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 3
# gamma: auto
# coef0: 0.0
# tol: 0.003048722384859225
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16515746747570015
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: auto
# coef0: 0.5
# tol: 0.007847693381458416
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16516510920254715
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.5
# tol: 0.007554414329227973
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16516510920254715
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.008118391526861756
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16516510920254715
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.5
# tol: 0.0027389628274289354
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16516617926659433
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 4
# gamma: scale
# coef0: 0.1
# tol: 0.0017408457016932883
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.1653830612431429
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: auto
# coef0: 0.0
# tol: 0.001852831319009668
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.1653830612431429
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: scale
# coef0: 0.30000000000000004
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16541230188847816
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16541230188847816
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: scale
# coef0: 0.8
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16541230188847816
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16541230188847816
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: scale
# coef0: 0.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16541230188847816
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0007245932496350248
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.1654310102620608
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.9
# tol: 0.002116715159322053
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16543229864915596
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.0010000000000001108
# shrinking: True
# Score: -0.1654489703283319
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: scale
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.30000000000000004
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001000000000000011
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.16544897032833195
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.8
# tol: 0.0062195041644489985
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.1655890876606645
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.009717758724247445
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.1656043381212485
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: auto
# coef0: 0.2
# tol: 0.0001
# C: 1.0
# epsilon: 0.001
# shrinking: False
# Score: -0.1721092281274616
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.2
# tol: 0.0001
# C: 1.0
# epsilon: 0.001
# shrinking: False
# Score: -0.1721092281274616
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 2
# gamma: scale
# coef0: 0.0
# tol: 0.01
# C: 1.0
# epsilon: 0.001
# shrinking: False
# Score: -0.17221172890055506
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.1
# tol: 0.00402892656245834
# C: 1.0
# epsilon: 0.001
# shrinking: False
# Score: -0.17225602032188586
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.17686524838155043
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.01
# C: 0.1
# epsilon: 0.001
# shrinking: False
# Score: -0.17765790821442862
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 4
# gamma: scale
# coef0: 0.2
# tol: 0.0001
# C: 0.1
# epsilon: 0.31496662515056556
# shrinking: False
# Score: -0.21527094253430712
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 6
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.005818320768359006
# C: 10.0
# epsilon: 0.3394205498222679
# shrinking: False
# Score: -0.22103766917070358
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 10
# gamma: auto
# coef0: 1.0
# tol: 0.004828398234012264
# C: 0.1
# epsilon: 0.33152164523010347
# shrinking: False
# Score: -0.22279927283105705
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 4
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.003796646398547297
# C: 0.1
# epsilon: 0.07574126049086873
# shrinking: False
# Score: -0.2235878849894135
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 4
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.0021203562665160283
# C: 10.0
# epsilon: 0.001
# shrinking: False
# Score: -0.22536070252124954
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: auto
# coef0: 0.5
# tol: 0.01
# C: 10.0
# epsilon: 0.001
# shrinking: False
# Score: -0.2287545309671389
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 7
# gamma: scale
# coef0: 0.2
# tol: 0.0054610889610008755
# C: 100.0
# epsilon: 0.15598435870817345
# shrinking: True
# Score: -0.23064661782792523
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 3
# gamma: auto
# coef0: 0.30000000000000004
# tol: 0.008094579636098997
# C: 10.0
# epsilon: 0.37952076669316026
# shrinking: True
# Score: -0.2393414014590057
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 4
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.004443370963331667
# C: 1.0
# epsilon: 0.37456405230782824
# shrinking: True
# Score: -0.2459606849791592
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 6
# gamma: auto
# coef0: 0.0
# tol: 0.004827540082771725
# C: 100.0
# epsilon: 0.4187954642334778
# shrinking: True
# Score: -0.24753894250566502
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 8
# gamma: scale
# coef0: 0.2
# tol: 0.006018597461163295
# C: 100.0
# epsilon: 0.39371350158103097
# shrinking: False
# Score: -0.2479727349358821
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 8
# gamma: scale
# coef0: 0.9
# tol: 0.0014683658641631856
# C: 0.1
# epsilon: 0.9373044338862097
# shrinking: True
# Score: -0.2509521572799002
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 2
# gamma: scale
# coef0: 0.7000000000000001
# tol: 0.0025127479899484497
# C: 1000.0
# epsilon: 0.7136855487126776
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 5
# gamma: auto
# coef0: 0.7000000000000001
# tol: 0.0030348030473615834
# C: 1.0
# epsilon: 0.6034120996622898
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 3
# gamma: scale
# coef0: 0.1
# tol: 0.004319721497694725
# C: 10.0
# epsilon: 0.63908304044091
# shrinking: False
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 8
# gamma: auto
# coef0: 0.0
# tol: 0.006470340068239552
# C: 1000.0
# epsilon: 0.5562164238483878
# shrinking: False
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 8
# gamma: auto
# coef0: 0.2
# tol: 0.005954119457858383
# C: 10.0
# epsilon: 0.7064007901549582
# shrinking: False
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 8
# gamma: scale
# coef0: 0.5
# tol: 0.006675690284869233
# C: 10.0
# epsilon: 0.6678362049185769
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 3
# gamma: scale
# coef0: 0.5
# tol: 0.009298285961141774
# C: 0.1
# epsilon: 0.9751888665264181
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: rbf
# degree: 6
# gamma: auto
# coef0: 0.9
# tol: 0.008426429873323366
# C: 1.0
# epsilon: 0.5641111117884595
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 4
# gamma: scale
# coef0: 0.8
# tol: 0.004971325770716916
# C: 0.1
# epsilon: 0.9901727689100299
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 7
# gamma: scale
# coef0: 0.9
# tol: 0.007078614513064529
# C: 100.0
# epsilon: 0.6297086612322574
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: linear
# degree: 2
# gamma: scale
# coef0: 0.8
# tol: 0.004060283640354045
# C: 10.0
# epsilon: 0.7095738410132454
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 8
# gamma: auto
# coef0: 0.2
# tol: 0.0028592065987744285
# C: 100.0
# epsilon: 0.9431300975603121
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 4
# gamma: scale
# coef0: 0.7000000000000001
# tol: 0.006665162895329897
# C: 1.0
# epsilon: 0.5970234697658869
# shrinking: True
# Score: -0.2509521572799003
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 4
# gamma: scale
# coef0: 0.6000000000000001
# tol: 0.005836578791874713
# C: 0.1
# epsilon: 0.9266446219072889
# shrinking: False
# Score: -0.25095215727990033
# Trial summary
# Hyperparameters:
# kernel: poly
# degree: 10
# gamma: auto
# coef0: 0.0
# tol: 0.0001
# C: 0.1
# epsilon: 0.001
# shrinking: True
# Score: -0.28663621953397944

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model
# Out:
# SVR(coef0=0.30000000000000004, degree=5, epsilon=0.09061434370161621,
#     kernel='linear', shrinking=False, tol=0.0006266295958271196)

# %%
import numpy as np

best_hps = tuner.get_best_hyperparameters(10)
model = build_model(best_hps[0])
model.fit(train_X, train_y)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(coef0=0.30000000000000004, degree=5, epsilon=0.09061434370161621,
#     kernel='linear', shrinking=False, tol=0.0006266295958271196)

# %%
train_y = train_y.reshape((len(train_y), 1))
inv_y = np.concatenate((train_y, train_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

pred = model.predict(train_X)
pred = pred.reshape((len(pred), 1))
inv_yhat = np.concatenate((pred, train_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

train_result = pd.DataFrame({'actual': inv_y, 'pred': inv_yhat}, index=reframed.loc[:train_end].index)

# %%
plt.plot(train_result['actual'], label='train_actual')
plt.plot(train_result['pred'], label='train_pred')
plt.legend()
plt.show()

# %%
def mape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
from sklearn.metrics import r2_score

rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Train R-Squared: {r2_score(inv_y, inv_yhat) * 100:.3f}%')
print(f'Train RMSE: {rmse:.3f}')
print(f'Train MAPE: {mape(inv_y, inv_yhat):.3f}%')
# Out:
# Train R-Squared: 71.763%
# Train RMSE: 18.773
# Train MAPE: 13.975%

# %%
rmse_each_month = []
for index, value in train_result.iterrows():
    rmse_each_month.append(round(mean_squared_error([value['actual']], [value['pred']], squared=False), 2))
train_result['rmse'] = rmse_each_month

# %%
mape_each_month = []
for index, value in train_result.iterrows():
    mape_each_month.append(f"{round(mape([value['actual']], [value['pred']]), 2)}%")
train_result['mape'] = mape_each_month

# %%
train_result
# Out:
#             actual        pred   rmse    mape
# tanggal
# 2010-04-30   118.3  102.644469  15.66  13.23%
# 2010-05-31   124.3  131.332317   7.03   5.66%
# 2010-06-30   102.4  135.282175  32.88  32.11%
# 2010-07-31   102.3  114.579990  12.28   12.0%
# 2010-08-31   115.5  112.156082   3.34    2.9%
# 2010-09-30   110.5  123.901622  13.40  12.13%
# 2010-10-31   146.9  114.608930  32.29  21.98%
# 2010-11-30   137.7  122.296258  15.40  11.19%
# 2010-12-31    67.8  114.872473  47.07  69.43%
# 2011-01-31    79.6   95.261624  15.66  19.68%
# 2011-02-28    94.6  101.648053   7.05   7.45%
# 2011-03-31    77.6   95.065646  17.47  22.51%
# 2011-04-30   123.9  108.189747  15.71  12.68%
# 2011-05-31   153.0  137.384607  15.62  10.21%
# 2011-06-30   148.9  139.489945   9.41   6.32%
# 2011-07-31   144.7  145.071443   0.37   0.26%
# 2011-08-31   170.4  146.402222  24.00  14.08%
# 2011-09-30   185.3  169.645104  15.65   8.45%
# 2011-10-31   183.8  188.356940   4.56   2.48%
# 2011-11-30   187.6  175.173904  12.43   6.62%
# 2011-12-31   163.6  160.132408   3.47   2.12%

# %%
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

pred = model.predict(test_X)
pred = pred.reshape((len(pred), 1))
inv_yhat = np.concatenate((pred, test_X), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

test_result = pd.DataFrame({'actual': inv_y, 'pred': inv_yhat}, index=reframed.loc[test_start:test_end].index)

# %%
plt.plot(test_result['actual'], label='test_actual')
plt.plot(test_result['pred'], label='test_pred')
plt.legend()
plt.show()

# %%
rmse_each_month = []
for index, value in test_result.iterrows():
    rmse_each_month.append(round(mean_squared_error([value['actual']], [value['pred']], squared=False), 2))
test_result['rmse'] = rmse_each_month

# %%
mape_each_month = []
for index, value in test_result.iterrows():
    mape_each_month.append(f"{round(mape([value['actual']], [value['pred']]), 2)}%")
test_result['mape'] = mape_each_month

# %%
rmse = mean_squared_error(inv_y, inv_yhat, squared=False)
print(f'Test R-Squared: {r2_score(inv_y, inv_yhat) * 100:.3f}%')
print(f'Test RMSE: {rmse:.3f}')
print(f'Test MAPE: {mape(inv_y, inv_yhat):.3f}%')
# Out:
# Test R-Squared: -6.749%
# Test RMSE: 42.757
# Test MAPE: 38.187%

# %%
test_result
# Out:
#             actual        pred   rmse    mape
# tanggal
# 2012-01-31   156.7  133.434739  23.27  14.85%
# 2012-02-29   180.3  120.671186  59.63  33.07%
# 2012-03-31   166.4  127.941050  38.46  23.11%
# 2012-04-30   203.9  140.203440  63.70  31.24%
# 2012-05-31   181.5  152.522023  28.98  15.97%
# ...            ...         ...    ...     ...
# 2019-08-31   143.1  168.661411  25.56  17.86%
# 2019-09-30   140.4  181.954435  41.55   29.6%
# 2019-10-31   159.5  173.270042  13.77   8.63%
# 2019-11-30   162.7  182.627527  19.93  12.25%
# 2019-12-31   123.3  179.794663  56.49  45.82%
#
# [96 rows x 4 columns]
